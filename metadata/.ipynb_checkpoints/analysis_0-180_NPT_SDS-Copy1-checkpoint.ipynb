# %%
import os
import numpy as np
import mdtraj as md
import matplotlib.pyplot as plt

# === 產生 C1 / C12 index ===
def get_C1_C12_indices(num_sds, C1_start=749, C12_start=760, atoms_per_sds=42):
    C1_list = [C1_start + i*atoms_per_sds for i in range(num_sds)]
    C12_list = [C12_start + i*atoms_per_sds for i in range(num_sds)]
    return C1_list, C12_list

# === 計算多個 sds 主軸向量 ===
def calculate_main_axis_multi(traj, C1_list, C12_list):
    num_frames = traj.n_frames
    num_sds = len(C1_list)
    main_axis_all = np.zeros((num_frames, num_sds, 3))

    for i, (c1, c12) in enumerate(zip(C1_list, C12_list)):
        pos1 = traj.xyz[:, c1, :]
        pos8 = traj.xyz[:, c12, :]
        axis = pos8 - pos1
        norm = np.linalg.norm(axis, axis=1)[:, np.newaxis]
        main_axis_all[:, i, :] = axis / norm

    return main_axis_all

# === 計算 CNT z 向量 ===
def calculate_z_vector(traj, CNT_index1, CNT_index2):
    pos1 = traj.xyz[:, CNT_index1, :]
    pos2 = traj.xyz[:, CNT_index2, :]
    z_vector = pos2 - pos1
    norm = np.linalg.norm(z_vector, axis=1)[:, np.newaxis]
    return z_vector / norm

# === 分析多個 sds 方向 (0~180° 判斷) ===
def analyze_orientation_multi(traj, C1_list, C12_list, CNT_index1, CNT_index2):
    main_axis = calculate_main_axis_multi(traj, C1_list, C12_list)  # (frames, sds, 3)
    z_vector = calculate_z_vector(traj, CNT_index1, CNT_index2)    # (frames, 3)
    z_vector_expanded = z_vector[:, np.newaxis, :]                  # (frames, 1, 3)

    # dot product → cosθ，範圍 -1~1
    cos_theta = np.sum(main_axis * z_vector_expanded, axis=2)

    # 角度範圍 0–180°
    angles_deg = np.degrees(np.arccos(cos_theta))

    # P2 order parameter
    p2 = 0.5 * (3 * cos_theta**2 - 1)

    # 判斷直立/躺平
    orientation = np.where((angles_deg >= 45) & (angles_deg <= 135), 'upright', 'flat')

    return p2, angles_deg, orientation

# === 載入軌跡 ===
trj_file1 = "/work/jane/nano/NPT/explicit/2mrg_sds200/run_00/mrg_sds_200_i.dcd"
pdb_file1 = "/home/jane/nano/add_ion/NPT/explicit/2mrg_sds200/mrg_sds_200_i.pdb"
traj_CF_straight_o_00 = md.load(trj_file1, top=pdb_file1, stride=20)

# === 設定 sds 和 CNT ===
num_sds = 200
C1_list, C12_list = get_C1_C12_indices(num_sds)
CNT_index1 = 51    # 根據你的系統調整
CNT_index2 = 511   # 根據你的系統調整

# === 執行分析 ===
p2_values, angles, orientation_labels = analyze_orientation_multi(
    traj_CF_straight_o_00, C1_list, C12_list, CNT_index1, CNT_index2
)

# === 計算各幀平均 P2 和直立比例 ===
avg_p2 = np.mean(p2_values, axis=1)
upright_ratio = np.mean(orientation_labels == 'upright', axis=1)

# =====將 angles 展平成一維=======
angles_flat = angles.flatten()

# === Histogram (0–180°) ===
bins = 36  # 每 bin = 5 度
counts, bin_edges = np.histogram(angles_flat, bins=bins, range=(0,180))

# 計算每個 bin 中心
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
bar_width = bin_edges[1] - bin_edges[0]

# 分組 mask
upright_mask = (bin_centers >= 45) & (bin_centers <= 135)
flat_mask = ~upright_mask

plt.figure(figsize=(10,6))

# 畫 histogram：分成直立 / 躺平
plt.bar(bin_centers[flat_mask], counts[flat_mask], width=bar_width, 
        color='green', edgecolor='black', label='Flat (0–45,135–180)')
plt.bar(bin_centers[upright_mask], counts[upright_mask], width=bar_width, 
        color='blue', edgecolor='black', label='Upright (45–135)')

# 閾值線
plt.axvline(45, color='red', linestyle='--')
#plt.axvline(135, color='red', linestyle='--', label='Thresholds (45°,135°)')
plt.tick_params(axis='both', which='major', labelsize=18)

# 標籤與標題
plt.xlabel("Angle (degrees)", fontsize=24)
plt.ylabel("Frequency", fontsize=24)
#plt.title("Angle distribution (0–180°), 5°/bin ", fontsize=22)
plt.legend(fontsize=14, loc='upper center')
plt.xticks([0, 45, 90, 135, 180])



plt.show()

# === 統計直立 / 平躺數量 ===
upright_count = np.sum(orientation_labels == 'upright')
flat_count = np.sum(orientation_labels == 'flat')

print(f"Total frames x sds analyzed: {orientation_labels.size}")
print(f"Upright count: {upright_count}")
print(f"Flat count: {flat_count}")
print(f"Upright ratio (upright/total): {upright_count/orientation_labels.size}")

# === 範例輸出前 500 幀結果 (每個 sds) ===
for i in range(500):
    print(f"Frame {i}:")
    for j in range(num_sds):
        print(f"  SDS {j+1}: angle={angles[i,j]:.2f}°, P2={p2_values[i,j]:.3f}, {orientation_labels[i,j]}")
# Out:
# Total frames x sds analyzed: 100000
# Upright count: 58491
# Flat count: 41509
# Upright ratio (upright/total): 0.58491
# Frame 0:
#   SDS 1: angle=96.15°, P2=-0.483, upright
#   SDS 2: angle=126.55°, P2=0.032, upright
#   SDS 3: angle=118.58°, P2=-0.157, upright
#   SDS 4: angle=122.77°, P2=-0.060, upright
#   SDS 5: angle=123.78°, P2=-0.036, upright
#   SDS 6: angle=109.52°, P2=-0.333, upright
#   SDS 7: angle=121.95°, P2=-0.080, upright
#   SDS 8: angle=122.77°, P2=-0.060, upright
#   SDS 9: angle=122.76°, P2=-0.061, upright
#   SDS 10: angle=118.80°, P2=-0.152, upright
#   SDS 11: angle=97.50°, P2=-0.474, upright
#   SDS 12: angle=136.17°, P2=0.281, flat
#   SDS 13: angle=96.26°, P2=-0.482, upright
#   SDS 14: angle=123.82°, P2=-0.035, upright
#   SDS 15: angle=101.18°, P2=-0.444, upright
#   SDS 16: angle=108.97°, P2=-0.341, upright
#   SDS 17: angle=106.89°, P2=-0.373, upright
#   SDS 18: angle=107.69°, P2=-0.361, upright
#   SDS 19: angle=95.68°, P2=-0.485, upright
#   SDS 20: angle=134.23°, P2=0.230, upright
#   SDS 21: angle=113.57°, P2=-0.260, upright
#   SDS 22: angle=124.10°, P2=-0.028, upright
#   SDS 23: angle=106.62°, P2=-0.377, upright
#   SDS 24: angle=118.35°, P2=-0.162, upright
#   SDS 25: angle=109.13°, P2=-0.339, upright
#   SDS 26: angle=148.43°, P2=0.589, flat
#   SDS 27: angle=122.54°, P2=-0.066, upright
#   SDS 28: angle=139.46°, P2=0.366, flat
#   SDS 29: angle=136.72°, P2=0.295, flat
#   SDS 30: angle=121.40°, P2=-0.093, upright
#   SDS 31: angle=110.15°, P2=-0.322, upright
#   SDS 32: angle=133.97°, P2=0.223, upright
#   SDS 33: angle=113.62°, P2=-0.259, upright
#   SDS 34: angle=94.41°, P2=-0.491, upright
#   SDS 35: angle=137.39°, P2=0.313, flat
#   SDS 36: angle=123.86°, P2=-0.034, upright
#   SDS 37: angle=130.42°, P2=0.131, upright
#   SDS 38: angle=104.72°, P2=-0.403, upright
#   SDS 39: angle=123.19°, P2=-0.051, upright
#   SDS 40: angle=134.85°, P2=0.246, upright
#   SDS 41: angle=133.84°, P2=0.220, upright
#   SDS 42: angle=102.44°, P2=-0.430, upright
#   SDS 43: angle=128.12°, P2=0.072, upright
#   SDS 44: angle=122.31°, P2=-0.071, upright
#   SDS 45: angle=129.88°, P2=0.117, upright
#   SDS 46: angle=114.98°, P2=-0.232, upright
#   SDS 47: angle=103.45°, P2=-0.419, upright
#   SDS 48: angle=138.15°, P2=0.332, flat
#   SDS 49: angle=119.41°, P2=-0.138, upright
#   SDS 50: angle=138.83°, P2=0.350, flat
#   SDS 51: angle=120.61°, P2=-0.111, upright
#   SDS 52: angle=101.48°, P2=-0.441, upright
#   SDS 53: angle=113.56°, P2=-0.260, upright
#   SDS 54: angle=100.73°, P2=-0.448, upright
#   SDS 55: angle=126.52°, P2=0.031, upright
#   SDS 56: angle=122.59°, P2=-0.065, upright
#   SDS 57: angle=117.03°, P2=-0.190, upright
#   SDS 58: angle=121.32°, P2=-0.095, upright
#   SDS 59: angle=100.69°, P2=-0.448, upright
#   SDS 60: angle=107.06°, P2=-0.371, upright
#   SDS 61: angle=120.04°, P2=-0.124, upright
#   SDS 62: angle=132.97°, P2=0.197, upright
#   SDS 63: angle=138.34°, P2=0.337, flat
#   SDS 64: angle=125.36°, P2=0.002, upright
#   SDS 65: angle=120.84°, P2=-0.106, upright
#   SDS 66: angle=122.32°, P2=-0.071, upright
#   SDS 67: angle=143.02°, P2=0.457, flat
#   SDS 68: angle=120.06°, P2=-0.124, upright
#   SDS 69: angle=125.00°, P2=-0.007, upright
#   SDS 70: angle=137.04°, P2=0.303, flat
#   SDS 71: angle=155.36°, P2=0.739, flat
#   SDS 72: angle=119.14°, P2=-0.144, upright
#   SDS 73: angle=128.89°, P2=0.091, upright
#   SDS 74: angle=129.94°, P2=0.118, upright
#   SDS 75: angle=129.02°, P2=0.094, upright
#   SDS 76: angle=88.76°, P2=-0.499, upright
#   SDS 77: angle=123.41°, P2=-0.045, upright
#   SDS 78: angle=124.28°, P2=-0.024, upright
#   SDS 79: angle=137.38°, P2=0.312, flat
#   SDS 80: angle=128.34°, P2=0.077, upright
#   SDS 81: angle=121.00°, P2=-0.102, upright
#   SDS 82: angle=128.06°, P2=0.070, upright
#   SDS 83: angle=122.87°, P2=-0.058, upright
#   SDS 84: angle=87.35°, P2=-0.497, upright
#   SDS 85: angle=124.97°, P2=-0.007, upright
#   SDS 86: angle=112.49°, P2=-0.280, upright
#   SDS 87: angle=98.17°, P2=-0.470, upright
#   SDS 88: angle=108.88°, P2=-0.343, upright
#   SDS 89: angle=125.29°, P2=0.001, upright
#   SDS 90: angle=124.04°, P2=-0.030, upright
#   SDS 91: angle=112.54°, P2=-0.280, upright
#   SDS 92: angle=90.31°, P2=-0.500, upright
#   SDS 93: angle=114.50°, P2=-0.242, upright
#   SDS 94: angle=101.43°, P2=-0.441, upright
#   SDS 95: angle=139.75°, P2=0.374, flat
#   SDS 96: angle=110.32°, P2=-0.319, upright
#   SDS 97: angle=116.73°, P2=-0.197, upright
#   SDS 98: angle=113.16°, P2=-0.268, upright
#   SDS 99: angle=139.27°, P2=0.361, flat
#   SDS 100: angle=106.12°, P2=-0.384, upright
#   SDS 101: angle=95.43°, P2=-0.487, upright
#   SDS 102: angle=149.16°, P2=0.606, flat
#   SDS 103: angle=126.95°, P2=0.042, upright
#   SDS 104: angle=127.24°, P2=0.049, upright
#   SDS 105: angle=162.74°, P2=0.868, flat
#   SDS 106: angle=106.63°, P2=-0.377, upright
#   SDS 107: angle=116.22°, P2=-0.207, upright
#   SDS 108: angle=107.35°, P2=-0.367, upright
#   SDS 109: angle=117.60°, P2=-0.178, upright
#   SDS 110: angle=128.27°, P2=0.075, upright
#   SDS 111: angle=114.44°, P2=-0.243, upright
#   SDS 112: angle=93.78°, P2=-0.493, upright
#   SDS 113: angle=115.94°, P2=-0.213, upright
#   SDS 114: angle=128.69°, P2=0.086, upright
#   SDS 115: angle=115.43°, P2=-0.223, upright
#   SDS 116: angle=118.20°, P2=-0.165, upright
#   SDS 117: angle=119.30°, P2=-0.141, upright
#   SDS 118: angle=101.92°, P2=-0.436, upright
#   SDS 119: angle=127.37°, P2=0.053, upright
#   SDS 120: angle=133.07°, P2=0.199, upright
#   SDS 121: angle=135.10°, P2=0.253, flat
#   SDS 122: angle=120.78°, P2=-0.107, upright
#   SDS 123: angle=139.29°, P2=0.362, flat
#   SDS 124: angle=127.83°, P2=0.064, upright
#   SDS 125: angle=118.69°, P2=-0.154, upright
#   SDS 126: angle=146.61°, P2=0.546, flat
#   SDS 127: angle=113.24°, P2=-0.267, upright
#   SDS 128: angle=127.28°, P2=0.050, upright
#   SDS 129: angle=127.42°, P2=0.054, upright
#   SDS 130: angle=126.81°, P2=0.038, upright
#   SDS 131: angle=119.92°, P2=-0.127, upright
#   SDS 132: angle=141.64°, P2=0.422, flat
#   SDS 133: angle=125.29°, P2=0.001, upright
#   SDS 134: angle=101.21°, P2=-0.443, upright
#   SDS 135: angle=108.59°, P2=-0.348, upright
#   SDS 136: angle=112.93°, P2=-0.272, upright
#   SDS 137: angle=120.93°, P2=-0.104, upright
#   SDS 138: angle=112.36°, P2=-0.283, upright
#   SDS 139: angle=124.84°, P2=-0.011, upright
#   SDS 140: angle=125.62°, P2=0.009, upright
#   SDS 141: angle=111.70°, P2=-0.295, upright
#   SDS 142: angle=116.32°, P2=-0.205, upright
#   SDS 143: angle=138.93°, P2=0.353, flat
#   SDS 144: angle=132.31°, P2=0.180, upright
#   SDS 145: angle=122.26°, P2=-0.073, upright
#   SDS 146: angle=114.22°, P2=-0.247, upright
#   SDS 147: angle=124.56°, P2=-0.017, upright
#   SDS 148: angle=105.95°, P2=-0.387, upright
#   SDS 149: angle=132.75°, P2=0.191, upright
#   SDS 150: angle=109.11°, P2=-0.339, upright
#   SDS 151: angle=135.75°, P2=0.270, flat
#   SDS 152: angle=122.17°, P2=-0.075, upright
#   SDS 153: angle=136.37°, P2=0.286, flat
#   SDS 154: angle=102.82°, P2=-0.426, upright
#   SDS 155: angle=123.99°, P2=-0.031, upright
#   SDS 156: angle=92.74°, P2=-0.497, upright
#   SDS 157: angle=113.44°, P2=-0.263, upright
#   SDS 158: angle=112.95°, P2=-0.272, upright
#   SDS 159: angle=106.45°, P2=-0.380, upright
#   SDS 160: angle=119.76°, P2=-0.131, upright
#   SDS 161: angle=147.76°, P2=0.573, flat
#   SDS 162: angle=134.15°, P2=0.228, upright
#   SDS 163: angle=120.13°, P2=-0.122, upright
#   SDS 164: angle=120.54°, P2=-0.113, upright
#   SDS 165: angle=118.72°, P2=-0.154, upright
#   SDS 166: angle=80.80°, P2=-0.462, upright
#   SDS 167: angle=120.84°, P2=-0.106, upright
#   SDS 168: angle=123.38°, P2=-0.046, upright
#   SDS 169: angle=109.92°, P2=-0.326, upright
#   SDS 170: angle=124.20°, P2=-0.026, upright
#   SDS 171: angle=112.17°, P2=-0.286, upright
#   SDS 172: angle=124.16°, P2=-0.027, upright
#   SDS 173: angle=112.87°, P2=-0.274, upright
#   SDS 174: angle=150.06°, P2=0.626, flat
#   SDS 175: angle=136.69°, P2=0.294, flat
#   SDS 176: angle=131.16°, P2=0.150, upright
#   SDS 177: angle=105.90°, P2=-0.387, upright
#   SDS 178: angle=133.41°, P2=0.208, upright
#   SDS 179: angle=138.39°, P2=0.338, flat
#   SDS 180: angle=87.47°, P2=-0.497, upright
#   SDS 181: angle=121.30°, P2=-0.095, upright
#   SDS 182: angle=127.87°, P2=0.065, upright
#   SDS 183: angle=113.60°, P2=-0.260, upright
#   SDS 184: angle=113.64°, P2=-0.259, upright
#   SDS 185: angle=122.39°, P2=-0.070, upright
#   SDS 186: angle=132.26°, P2=0.178, upright
#   SDS 187: angle=134.39°, P2=0.234, upright
#   SDS 188: angle=125.14°, P2=-0.003, upright
#   SDS 189: angle=102.88°, P2=-0.425, upright
#   SDS 190: angle=142.70°, P2=0.449, flat
#   SDS 191: angle=140.99°, P2=0.406, flat
#   SDS 192: angle=106.47°, P2=-0.379, upright
#   SDS 193: angle=111.89°, P2=-0.292, upright
#   SDS 194: angle=132.84°, P2=0.194, upright
#   SDS 195: angle=116.38°, P2=-0.204, upright
#   SDS 196: angle=137.42°, P2=0.313, flat
#   SDS 197: angle=121.43°, P2=-0.092, upright
#   SDS 198: angle=103.49°, P2=-0.418, upright
#   SDS 199: angle=123.71°, P2=-0.038, upright
#   SDS 200: angle=101.52°, P2=-0.440, upright
# Frame 1:
#   SDS 1: angle=55.54°, P2=-0.020, upright
#   SDS 2: angle=123.51°, P2=-0.043, upright
#   SDS 3: angle=121.90°, P2=-0.081, upright
#   SDS 4: angle=159.08°, P2=0.809, flat
#   SDS 5: angle=130.69°, P2=0.138, upright
#   SDS 6: angle=73.39°, P2=-0.377, upright
#   SDS 7: angle=104.69°, P2=-0.404, upright
#   SDS 8: angle=79.37°, P2=-0.449, upright
#   SDS 9: angle=64.09°, P2=-0.214, upright
#   SDS 10: angle=98.04°, P2=-0.471, upright
#   SDS 11: angle=93.29°, P2=-0.495, upright
#   SDS 12: angle=88.66°, P2=-0.499, upright
#   SDS 13: angle=75.38°, P2=-0.404, upright
#   SDS 14: angle=82.86°, P2=-0.477, upright
#   SDS 15: angle=130.33°, P2=0.128, upright
#   SDS 16: angle=110.57°, P2=-0.315, upright
#   SDS 17: angle=107.74°, P2=-0.361, upright
#   SDS 18: angle=26.07°, P2=0.710, flat
#   SDS 19: angle=96.00°, P2=-0.484, upright
#   SDS 20: angle=101.80°, P2=-0.437, upright
#   SDS 21: angle=70.43°, P2=-0.332, upright
#   SDS 22: angle=98.53°, P2=-0.467, upright
#   SDS 23: angle=96.31°, P2=-0.482, upright
#   SDS 24: angle=105.76°, P2=-0.389, upright
#   SDS 25: angle=94.08°, P2=-0.492, upright
#   SDS 26: angle=107.85°, P2=-0.359, upright
#   SDS 27: angle=170.09°, P2=0.956, flat
#   SDS 28: angle=148.52°, P2=0.591, flat
#   SDS 29: angle=139.70°, P2=0.373, flat
#   SDS 30: angle=125.24°, P2=-0.001, upright
#   SDS 31: angle=76.97°, P2=-0.424, upright
#   SDS 32: angle=131.05°, P2=0.147, upright
#   SDS 33: angle=174.75°, P2=0.987, flat
#   SDS 34: angle=89.24°, P2=-0.500, upright
#   SDS 35: angle=93.66°, P2=-0.494, upright
#   SDS 36: angle=132.93°, P2=0.196, upright
#   SDS 37: angle=109.09°, P2=-0.340, upright
#   SDS 38: angle=57.33°, P2=-0.063, upright
#   SDS 39: angle=42.44°, P2=0.317, flat
#   SDS 40: angle=153.62°, P2=0.704, flat
#   SDS 41: angle=173.75°, P2=0.982, flat
#   SDS 42: angle=66.26°, P2=-0.257, upright
#   SDS 43: angle=106.92°, P2=-0.373, upright
#   SDS 44: angle=117.88°, P2=-0.172, upright
#   SDS 45: angle=150.44°, P2=0.635, flat
#   SDS 46: angle=138.56°, P2=0.343, flat
#   SDS 47: angle=93.16°, P2=-0.495, upright
#   SDS 48: angle=104.04°, P2=-0.412, upright
#   SDS 49: angle=46.28°, P2=0.216, upright
#   SDS 50: angle=134.10°, P2=0.226, upright
#   SDS 51: angle=127.07°, P2=0.045, upright
#   SDS 52: angle=115.49°, P2=-0.222, upright
#   SDS 53: angle=85.10°, P2=-0.489, upright
#   SDS 54: angle=125.68°, P2=0.010, upright
#   SDS 55: angle=68.64°, P2=-0.301, upright
#   SDS 56: angle=128.14°, P2=0.072, upright
#   SDS 57: angle=115.60°, P2=-0.220, upright
#   SDS 58: angle=96.65°, P2=-0.480, upright
#   SDS 59: angle=85.73°, P2=-0.492, upright
#   SDS 60: angle=67.03°, P2=-0.272, upright
#   SDS 61: angle=79.03°, P2=-0.446, upright
#   SDS 62: angle=104.63°, P2=-0.404, upright
#   SDS 63: angle=114.36°, P2=-0.245, upright
#   SDS 64: angle=87.66°, P2=-0.498, upright
#   SDS 65: angle=65.17°, P2=-0.235, upright
#   SDS 66: angle=136.36°, P2=0.286, flat
#   SDS 67: angle=125.89°, P2=0.015, upright
#   SDS 68: angle=108.57°, P2=-0.348, upright
#   SDS 69: angle=150.11°, P2=0.627, flat
#   SDS 70: angle=112.84°, P2=-0.274, upright
#   SDS 71: angle=108.06°, P2=-0.356, upright
#   SDS 72: angle=163.93°, P2=0.885, flat
#   SDS 73: angle=132.68°, P2=0.189, upright
#   SDS 74: angle=73.57°, P2=-0.380, upright
#   SDS 75: angle=36.53°, P2=0.469, flat
#   SDS 76: angle=88.37°, P2=-0.499, upright
#   SDS 77: angle=105.31°, P2=-0.395, upright
#   SDS 78: angle=120.54°, P2=-0.113, upright
#   SDS 79: angle=88.06°, P2=-0.498, upright
#   SDS 80: angle=103.02°, P2=-0.424, upright
#   SDS 81: angle=119.51°, P2=-0.136, upright
#   SDS 82: angle=121.04°, P2=-0.101, upright
#   SDS 83: angle=146.55°, P2=0.544, flat
#   SDS 84: angle=46.04°, P2=0.223, upright
#   SDS 85: angle=41.16°, P2=0.350, flat
#   SDS 86: angle=151.10°, P2=0.650, flat
#   SDS 87: angle=75.12°, P2=-0.401, upright
#   SDS 88: angle=89.09°, P2=-0.500, upright
#   SDS 89: angle=125.46°, P2=0.005, upright
#   SDS 90: angle=130.92°, P2=0.143, upright
#   SDS 91: angle=101.53°, P2=-0.440, upright
#   SDS 92: angle=71.67°, P2=-0.352, upright
#   SDS 93: angle=118.61°, P2=-0.156, upright
#   SDS 94: angle=135.73°, P2=0.269, flat
#   SDS 95: angle=92.39°, P2=-0.497, upright
#   SDS 96: angle=142.49°, P2=0.444, flat
#   SDS 97: angle=133.33°, P2=0.206, upright
#   SDS 98: angle=116.06°, P2=-0.210, upright
#   SDS 99: angle=151.34°, P2=0.655, flat
#   SDS 100: angle=131.31°, P2=0.154, upright
#   SDS 101: angle=77.07°, P2=-0.425, upright
#   SDS 102: angle=101.97°, P2=-0.435, upright
#   SDS 103: angle=155.91°, P2=0.750, flat
#   SDS 104: angle=117.60°, P2=-0.178, upright
#   SDS 105: angle=114.67°, P2=-0.239, upright
#   SDS 106: angle=108.82°, P2=-0.344, upright
#   SDS 107: angle=131.01°, P2=0.146, upright
#   SDS 108: angle=75.33°, P2=-0.404, upright
#   SDS 109: angle=172.66°, P2=0.975, flat
#   SDS 110: angle=85.27°, P2=-0.490, upright
#   SDS 111: angle=87.76°, P2=-0.498, upright
#   SDS 112: angle=77.50°, P2=-0.430, upright
#   SDS 113: angle=82.83°, P2=-0.477, upright
#   SDS 114: angle=150.73°, P2=0.642, flat
#   SDS 115: angle=71.95°, P2=-0.356, upright
#   SDS 116: angle=64.91°, P2=-0.230, upright
#   SDS 117: angle=128.90°, P2=0.092, upright
#   SDS 118: angle=87.58°, P2=-0.497, upright
#   SDS 119: angle=112.72°, P2=-0.276, upright
#   SDS 120: angle=101.88°, P2=-0.436, upright
#   SDS 121: angle=110.88°, P2=-0.309, upright
#   SDS 122: angle=154.69°, P2=0.726, flat
#   SDS 123: angle=128.54°, P2=0.082, upright
#   SDS 124: angle=137.75°, P2=0.322, flat
#   SDS 125: angle=93.17°, P2=-0.495, upright
#   SDS 126: angle=102.12°, P2=-0.434, upright
#   SDS 127: angle=62.23°, P2=-0.174, upright
#   SDS 128: angle=128.54°, P2=0.082, upright
#   SDS 129: angle=138.07°, P2=0.330, flat
#   SDS 130: angle=159.61°, P2=0.818, flat
#   SDS 131: angle=110.28°, P2=-0.320, upright
#   SDS 132: angle=101.53°, P2=-0.440, upright
#   SDS 133: angle=139.04°, P2=0.356, flat
#   SDS 134: angle=98.83°, P2=-0.465, upright
#   SDS 135: angle=95.81°, P2=-0.485, upright
#   SDS 136: angle=85.41°, P2=-0.490, upright
#   SDS 137: angle=128.67°, P2=0.086, upright
#   SDS 138: angle=103.18°, P2=-0.422, upright
#   SDS 139: angle=100.75°, P2=-0.448, upright
#   SDS 140: angle=90.87°, P2=-0.500, upright
#   SDS 141: angle=48.17°, P2=0.167, upright
#   SDS 142: angle=107.22°, P2=-0.369, upright
#   SDS 143: angle=153.08°, P2=0.693, flat
#   SDS 144: angle=104.95°, P2=-0.400, upright
#   SDS 145: angle=146.31°, P2=0.539, flat
#   SDS 146: angle=172.58°, P2=0.975, flat
#   SDS 147: angle=93.23°, P2=-0.495, upright
#   SDS 148: angle=75.82°, P2=-0.410, upright
#   SDS 149: angle=105.67°, P2=-0.391, upright
#   SDS 150: angle=45.31°, P2=0.242, upright
#   SDS 151: angle=94.58°, P2=-0.490, upright
#   SDS 152: angle=89.53°, P2=-0.500, upright
#   SDS 153: angle=122.54°, P2=-0.066, upright
#   SDS 154: angle=15.51°, P2=0.893, flat
#   SDS 155: angle=64.12°, P2=-0.214, upright
#   SDS 156: angle=128.21°, P2=0.074, upright
#   SDS 157: angle=89.68°, P2=-0.500, upright
#   SDS 158: angle=106.42°, P2=-0.380, upright
#   SDS 159: angle=47.61°, P2=0.182, upright
#   SDS 160: angle=137.77°, P2=0.322, flat
#   SDS 161: angle=117.04°, P2=-0.190, upright
#   SDS 162: angle=140.95°, P2=0.405, flat
#   SDS 163: angle=88.86°, P2=-0.499, upright
#   SDS 164: angle=113.59°, P2=-0.260, upright
#   SDS 165: angle=105.20°, P2=-0.397, upright
#   SDS 166: angle=92.06°, P2=-0.498, upright
#   SDS 167: angle=132.24°, P2=0.178, upright
#   SDS 168: angle=134.76°, P2=0.244, upright
#   SDS 169: angle=114.92°, P2=-0.234, upright
#   SDS 170: angle=101.90°, P2=-0.436, upright
#   SDS 171: angle=83.95°, P2=-0.483, upright
#   SDS 172: angle=76.93°, P2=-0.423, upright
#   SDS 173: angle=101.66°, P2=-0.439, upright
#   SDS 174: angle=134.47°, P2=0.236, upright
#   SDS 175: angle=61.00°, P2=-0.148, upright
#   SDS 176: angle=123.88°, P2=-0.034, upright
#   SDS 177: angle=110.65°, P2=-0.313, upright
#   SDS 178: angle=76.49°, P2=-0.418, upright
#   SDS 179: angle=95.71°, P2=-0.485, upright
#   SDS 180: angle=86.37°, P2=-0.494, upright
#   SDS 181: angle=147.96°, P2=0.578, flat
#   SDS 182: angle=67.01°, P2=-0.271, upright
#   SDS 183: angle=102.31°, P2=-0.432, upright
#   SDS 184: angle=122.48°, P2=-0.067, upright
#   SDS 185: angle=142.10°, P2=0.434, flat
#   SDS 186: angle=123.77°, P2=-0.037, upright
#   SDS 187: angle=145.69°, P2=0.523, flat
#   SDS 188: angle=133.79°, P2=0.218, upright
#   SDS 189: angle=97.11°, P2=-0.477, upright
#   SDS 190: angle=105.00°, P2=-0.400, upright
#   SDS 191: angle=145.61°, P2=0.521, flat
#   SDS 192: angle=122.42°, P2=-0.069, upright
#   SDS 193: angle=50.52°, P2=0.106, upright
#   SDS 194: angle=149.39°, P2=0.611, flat
#   SDS 195: angle=147.40°, P2=0.564, flat
#   SDS 196: angle=136.94°, P2=0.301, flat
#   SDS 197: angle=82.49°, P2=-0.474, upright
#   SDS 198: angle=121.75°, P2=-0.085, upright
#   SDS 199: angle=122.45°, P2=-0.068, upright
#   SDS 200: angle=139.87°, P2=0.377, flat
# Frame 2:
#   SDS 1: angle=68.16°, P2=-0.292, upright
#   SDS 2: angle=141.56°, P2=0.420, flat
#   SDS 3: angle=116.58°, P2=-0.200, upright
#   SDS 4: angle=157.42°, P2=0.779, flat
#   SDS 5: angle=137.40°, P2=0.313, flat
#   SDS 6: angle=115.03°, P2=-0.231, upright
#   SDS 7: angle=89.84°, P2=-0.500, upright
#   SDS 8: angle=20.87°, P2=0.810, flat
#   SDS 9: angle=25.62°, P2=0.720, flat
#   SDS 10: angle=66.82°, P2=-0.268, upright
#   SDS 11: angle=94.80°, P2=-0.489, upright
#   SDS 12: angle=95.08°, P2=-0.488, upright
#   SDS 13: angle=117.24°, P2=-0.186, upright
#   SDS 14: angle=85.51°, P2=-0.491, upright
#   SDS 15: angle=151.44°, P2=0.657, flat
#   SDS 16: angle=87.88°, P2=-0.498, upright
#   SDS 17: angle=68.20°, P2=-0.293, upright
#   SDS 18: angle=68.15°, P2=-0.292, upright
#   SDS 19: angle=106.85°, P2=-0.374, upright
#   SDS 20: angle=68.29°, P2=-0.295, upright
#   SDS 21: angle=3.74°, P2=0.994, flat
#   SDS 22: angle=70.91°, P2=-0.340, upright
#   SDS 23: angle=116.56°, P2=-0.200, upright
#   SDS 24: angle=90.76°, P2=-0.500, upright
#   SDS 25: angle=68.46°, P2=-0.298, upright
#   SDS 26: angle=70.66°, P2=-0.336, upright
#   SDS 27: angle=135.61°, P2=0.266, flat
#   SDS 28: angle=155.62°, P2=0.744, flat
#   SDS 29: angle=105.50°, P2=-0.393, upright
#   SDS 30: angle=144.27°, P2=0.488, flat
#   SDS 31: angle=39.37°, P2=0.396, flat
#   SDS 32: angle=135.77°, P2=0.270, flat
#   SDS 33: angle=145.50°, P2=0.519, flat
#   SDS 34: angle=75.04°, P2=-0.400, upright
#   SDS 35: angle=106.07°, P2=-0.385, upright
#   SDS 36: angle=83.45°, P2=-0.480, upright
#   SDS 37: angle=68.02°, P2=-0.290, upright
#   SDS 38: angle=62.73°, P2=-0.185, upright
#   SDS 39: angle=60.44°, P2=-0.135, upright
#   SDS 40: angle=172.56°, P2=0.975, flat
#   SDS 41: angle=135.22°, P2=0.256, flat
#   SDS 42: angle=73.79°, P2=-0.383, upright
#   SDS 43: angle=156.82°, P2=0.768, flat
#   SDS 44: angle=131.45°, P2=0.157, upright
#   SDS 45: angle=124.85°, P2=-0.010, upright
#   SDS 46: angle=43.82°, P2=0.281, flat
#   SDS 47: angle=57.89°, P2=-0.076, upright
#   SDS 48: angle=97.27°, P2=-0.476, upright
#   SDS 49: angle=40.91°, P2=0.357, flat
#   SDS 50: angle=137.58°, P2=0.317, flat
#   SDS 51: angle=83.81°, P2=-0.483, upright
#   SDS 52: angle=101.25°, P2=-0.443, upright
#   SDS 53: angle=89.77°, P2=-0.500, upright
#   SDS 54: angle=134.32°, P2=0.232, upright
#   SDS 55: angle=116.98°, P2=-0.191, upright
#   SDS 56: angle=142.51°, P2=0.444, flat
#   SDS 57: angle=118.40°, P2=-0.161, upright
#   SDS 58: angle=107.08°, P2=-0.371, upright
#   SDS 59: angle=85.52°, P2=-0.491, upright
#   SDS 60: angle=95.61°, P2=-0.486, upright
#   SDS 61: angle=83.20°, P2=-0.479, upright
#   SDS 62: angle=148.69°, P2=0.595, flat
#   SDS 63: angle=78.58°, P2=-0.441, upright
#   SDS 64: angle=41.65°, P2=0.337, flat
#   SDS 65: angle=56.70°, P2=-0.048, upright
#   SDS 66: angle=115.35°, P2=-0.225, upright
#   SDS 67: angle=125.04°, P2=-0.006, upright
#   SDS 68: angle=77.28°, P2=-0.427, upright
#   SDS 69: angle=169.15°, P2=0.947, flat
#   SDS 70: angle=106.37°, P2=-0.381, upright
#   SDS 71: angle=119.83°, P2=-0.129, upright
#   SDS 72: angle=122.26°, P2=-0.073, upright
#   SDS 73: angle=136.41°, P2=0.287, flat
#   SDS 74: angle=131.92°, P2=0.170, upright
#   SDS 75: angle=18.70°, P2=0.846, flat
#   SDS 76: angle=65.58°, P2=-0.244, upright
#   SDS 77: angle=98.08°, P2=-0.470, upright
#   SDS 78: angle=116.55°, P2=-0.200, upright
#   SDS 79: angle=89.60°, P2=-0.500, upright
#   SDS 80: angle=70.08°, P2=-0.326, upright
#   SDS 81: angle=135.68°, P2=0.268, flat
#   SDS 82: angle=104.26°, P2=-0.409, upright
#   SDS 83: angle=125.05°, P2=-0.005, upright
#   SDS 84: angle=66.86°, P2=-0.268, upright
#   SDS 85: angle=35.76°, P2=0.488, flat
#   SDS 86: angle=161.26°, P2=0.845, flat
#   SDS 87: angle=55.25°, P2=-0.013, upright
#   SDS 88: angle=64.93°, P2=-0.231, upright
#   SDS 89: angle=149.79°, P2=0.620, flat
#   SDS 90: angle=128.02°, P2=0.069, upright
#   SDS 91: angle=100.38°, P2=-0.451, upright
#   SDS 92: angle=59.41°, P2=-0.112, upright
#   SDS 93: angle=108.57°, P2=-0.348, upright
#   SDS 94: angle=132.77°, P2=0.192, upright
#   SDS 95: angle=91.98°, P2=-0.498, upright
#   SDS 96: angle=144.15°, P2=0.485, flat
#   SDS 97: angle=143.03°, P2=0.458, flat
#   SDS 98: angle=101.64°, P2=-0.439, upright
#   SDS 99: angle=157.34°, P2=0.777, flat
#   SDS 100: angle=140.89°, P2=0.403, flat
#   SDS 101: angle=82.51°, P2=-0.474, upright
#   SDS 102: angle=125.72°, P2=0.011, upright
#   SDS 103: angle=164.82°, P2=0.897, flat
#   SDS 104: angle=128.64°, P2=0.085, upright
#   SDS 105: angle=138.15°, P2=0.332, flat
#   SDS 106: angle=105.50°, P2=-0.393, upright
#   SDS 107: angle=145.17°, P2=0.511, flat
#   SDS 108: angle=80.66°, P2=-0.461, upright
#   SDS 109: angle=146.60°, P2=0.545, flat
#   SDS 110: angle=111.27°, P2=-0.303, upright
#   SDS 111: angle=109.54°, P2=-0.332, upright
#   SDS 112: angle=23.52°, P2=0.761, flat
#   SDS 113: angle=12.46°, P2=0.930, flat
#   SDS 114: angle=138.36°, P2=0.338, flat
#   SDS 115: angle=65.33°, P2=-0.239, upright
#   SDS 116: angle=61.18°, P2=-0.152, upright
#   SDS 117: angle=101.49°, P2=-0.440, upright
#   SDS 118: angle=57.31°, P2=-0.062, upright
#   SDS 119: angle=108.17°, P2=-0.354, upright
#   SDS 120: angle=74.25°, P2=-0.390, upright
#   SDS 121: angle=118.41°, P2=-0.160, upright
#   SDS 122: angle=166.56°, P2=0.919, flat
#   SDS 123: angle=138.40°, P2=0.339, flat
#   SDS 124: angle=143.95°, P2=0.480, flat
#   SDS 125: angle=140.19°, P2=0.385, flat
#   SDS 126: angle=66.81°, P2=-0.267, upright
#   SDS 127: angle=24.86°, P2=0.735, flat
#   SDS 128: angle=130.84°, P2=0.141, upright
#   SDS 129: angle=117.04°, P2=-0.190, upright
#   SDS 130: angle=131.68°, P2=0.163, upright
#   SDS 131: angle=100.75°, P2=-0.448, upright
#   SDS 132: angle=101.43°, P2=-0.441, upright
#   SDS 133: angle=62.09°, P2=-0.171, upright
#   SDS 134: angle=81.59°, P2=-0.468, upright
#   SDS 135: angle=91.51°, P2=-0.499, upright
#   SDS 136: angle=58.62°, P2=-0.093, upright
#   SDS 137: angle=105.49°, P2=-0.393, upright
#   SDS 138: angle=97.35°, P2=-0.475, upright
#   SDS 139: angle=40.90°, P2=0.357, flat
#   SDS 140: angle=95.48°, P2=-0.486, upright
#   SDS 141: angle=43.11°, P2=0.299, flat
#   SDS 142: angle=78.92°, P2=-0.445, upright
#   SDS 143: angle=144.60°, P2=0.497, flat
#   SDS 144: angle=106.77°, P2=-0.375, upright
#   SDS 145: angle=145.68°, P2=0.523, flat
#   SDS 146: angle=159.06°, P2=0.808, flat
#   SDS 147: angle=73.42°, P2=-0.378, upright
#   SDS 148: angle=137.44°, P2=0.314, flat
#   SDS 149: angle=151.32°, P2=0.655, flat
#   SDS 150: angle=56.74°, P2=-0.049, upright
#   SDS 151: angle=83.15°, P2=-0.479, upright
#   SDS 152: angle=94.06°, P2=-0.492, upright
#   SDS 153: angle=151.60°, P2=0.661, flat
#   SDS 154: angle=14.38°, P2=0.907, flat
#   SDS 155: angle=125.11°, P2=-0.004, upright
#   SDS 156: angle=96.73°, P2=-0.479, upright
#   SDS 157: angle=111.72°, P2=-0.295, upright
#   SDS 158: angle=127.50°, P2=0.056, upright
#   SDS 159: angle=38.16°, P2=0.427, flat
#   SDS 160: angle=102.36°, P2=-0.431, upright
#   SDS 161: angle=150.67°, P2=0.640, flat
#   SDS 162: angle=160.08°, P2=0.826, flat
#   SDS 163: angle=62.09°, P2=-0.171, upright
#   SDS 164: angle=122.93°, P2=-0.057, upright
#   SDS 165: angle=110.78°, P2=-0.311, upright
#   SDS 166: angle=91.58°, P2=-0.499, upright
#   SDS 167: angle=94.97°, P2=-0.489, upright
#   SDS 168: angle=102.50°, P2=-0.430, upright
#   SDS 169: angle=113.08°, P2=-0.269, upright
#   SDS 170: angle=100.97°, P2=-0.446, upright
#   SDS 171: angle=75.94°, P2=-0.411, upright
#   SDS 172: angle=53.96°, P2=0.019, upright
#   SDS 173: angle=84.23°, P2=-0.485, upright
#   SDS 174: angle=158.34°, P2=0.796, flat
#   SDS 175: angle=46.68°, P2=0.206, upright
#   SDS 176: angle=99.76°, P2=-0.457, upright
#   SDS 177: angle=150.44°, P2=0.635, flat
#   SDS 178: angle=100.42°, P2=-0.451, upright
#   SDS 179: angle=81.27°, P2=-0.465, upright
#   SDS 180: angle=88.18°, P2=-0.498, upright
#   SDS 181: angle=166.79°, P2=0.922, flat
#   SDS 182: angle=30.15°, P2=0.622, flat
#   SDS 183: angle=63.83°, P2=-0.208, upright
#   SDS 184: angle=150.06°, P2=0.626, flat
#   SDS 185: angle=142.71°, P2=0.449, flat
#   SDS 186: angle=127.41°, P2=0.054, upright
#   SDS 187: angle=131.78°, P2=0.166, upright
#   SDS 188: angle=116.98°, P2=-0.191, upright
#   SDS 189: angle=131.76°, P2=0.165, upright
#   SDS 190: angle=4.99°, P2=0.989, flat
#   SDS 191: angle=129.17°, P2=0.098, upright
#   SDS 192: angle=173.28°, P2=0.979, flat
#   SDS 193: angle=52.60°, P2=0.053, upright
#   SDS 194: angle=141.76°, P2=0.425, flat
#   SDS 195: angle=128.16°, P2=0.073, upright
#   SDS 196: angle=104.53°, P2=-0.406, upright
#   SDS 197: angle=81.09°, P2=-0.464, upright
#   SDS 198: angle=126.90°, P2=0.041, upright
#   SDS 199: angle=129.86°, P2=0.116, upright
#   SDS 200: angle=151.67°, P2=0.662, flat
# Frame 3:
#   SDS 1: angle=73.15°, P2=-0.374, upright
#   SDS 2: angle=140.09°, P2=0.383, flat
#   SDS 3: angle=121.28°, P2=-0.096, upright
#   SDS 4: angle=172.58°, P2=0.975, flat
#   SDS 5: angle=44.48°, P2=0.264, flat
#   SDS 6: angle=78.18°, P2=-0.437, upright
#   SDS 7: angle=81.76°, P2=-0.469, upright
#   SDS 8: angle=18.16°, P2=0.854, flat
#   SDS 9: angle=32.15°, P2=0.575, flat
#   SDS 10: angle=21.83°, P2=0.793, flat
#   SDS 11: angle=52.03°, P2=0.068, upright
#   SDS 12: angle=153.87°, P2=0.709, flat
#   SDS 13: angle=85.08°, P2=-0.489, upright
#   SDS 14: angle=108.92°, P2=-0.342, upright
#   SDS 15: angle=151.47°, P2=0.658, flat
#   SDS 16: angle=42.23°, P2=0.322, flat
#   SDS 17: angle=69.25°, P2=-0.312, upright
#   SDS 18: angle=65.83°, P2=-0.248, upright
#   SDS 19: angle=58.64°, P2=-0.094, upright
#   SDS 20: angle=50.91°, P2=0.096, upright
#   SDS 21: angle=55.73°, P2=-0.024, upright
#   SDS 22: angle=54.21°, P2=0.013, upright
#   SDS 23: angle=93.02°, P2=-0.496, upright
#   SDS 24: angle=106.51°, P2=-0.379, upright
#   SDS 25: angle=29.60°, P2=0.634, flat
#   SDS 26: angle=65.60°, P2=-0.244, upright
#   SDS 27: angle=146.57°, P2=0.545, flat
#   SDS 28: angle=153.54°, P2=0.702, flat
#   SDS 29: angle=133.47°, P2=0.210, upright
#   SDS 30: angle=112.61°, P2=-0.278, upright
#   SDS 31: angle=22.97°, P2=0.772, flat
#   SDS 32: angle=132.31°, P2=0.180, upright
#   SDS 33: angle=123.34°, P2=-0.047, upright
#   SDS 34: angle=60.14°, P2=-0.128, upright
#   SDS 35: angle=106.91°, P2=-0.373, upright
#   SDS 36: angle=131.06°, P2=0.147, upright
#   SDS 37: angle=35.42°, P2=0.496, flat
#   SDS 38: angle=55.02°, P2=-0.007, upright
#   SDS 39: angle=46.86°, P2=0.201, upright
#   SDS 40: angle=117.57°, P2=-0.179, upright
#   SDS 41: angle=142.70°, P2=0.449, flat
#   SDS 42: angle=14.86°, P2=0.901, flat
#   SDS 43: angle=133.57°, P2=0.212, upright
#   SDS 44: angle=147.45°, P2=0.566, flat
#   SDS 45: angle=71.37°, P2=-0.347, upright
#   SDS 46: angle=22.63°, P2=0.778, flat
#   SDS 47: angle=39.85°, P2=0.384, flat
#   SDS 48: angle=66.81°, P2=-0.267, upright
#   SDS 49: angle=56.35°, P2=-0.039, upright
#   SDS 50: angle=135.71°, P2=0.269, flat
#   SDS 51: angle=108.24°, P2=-0.353, upright
#   SDS 52: angle=128.49°, P2=0.081, upright
#   SDS 53: angle=78.30°, P2=-0.438, upright
#   SDS 54: angle=126.90°, P2=0.041, upright
#   SDS 55: angle=130.55°, P2=0.134, upright
#   SDS 56: angle=163.73°, P2=0.882, flat
#   SDS 57: angle=112.59°, P2=-0.279, upright
#   SDS 58: angle=56.83°, P2=-0.051, upright
#   SDS 59: angle=86.23°, P2=-0.493, upright
#   SDS 60: angle=107.61°, P2=-0.363, upright
#   SDS 61: angle=44.74°, P2=0.257, flat
#   SDS 62: angle=83.16°, P2=-0.479, upright
#   SDS 63: angle=55.45°, P2=-0.017, upright
#   SDS 64: angle=26.61°, P2=0.699, flat
#   SDS 65: angle=54.37°, P2=0.009, upright
#   SDS 66: angle=122.47°, P2=-0.068, upright
#   SDS 67: angle=145.28°, P2=0.513, flat
#   SDS 68: angle=66.79°, P2=-0.267, upright
#   SDS 69: angle=138.34°, P2=0.337, flat
#   SDS 70: angle=138.96°, P2=0.353, flat
#   SDS 71: angle=154.48°, P2=0.722, flat
#   SDS 72: angle=112.52°, P2=-0.280, upright
#   SDS 73: angle=88.90°, P2=-0.499, upright
#   SDS 74: angle=146.26°, P2=0.537, flat
#   SDS 75: angle=18.58°, P2=0.848, flat
#   SDS 76: angle=41.16°, P2=0.350, flat
#   SDS 77: angle=167.14°, P2=0.926, flat
#   SDS 78: angle=50.58°, P2=0.105, upright
#   SDS 79: angle=83.72°, P2=-0.482, upright
#   SDS 80: angle=58.86°, P2=-0.099, upright
#   SDS 81: angle=171.77°, P2=0.969, flat
#   SDS 82: angle=65.61°, P2=-0.244, upright
#   SDS 83: angle=149.54°, P2=0.614, flat
#   SDS 84: angle=48.38°, P2=0.162, upright
#   SDS 85: angle=64.97°, P2=-0.231, upright
#   SDS 86: angle=161.89°, P2=0.855, flat
#   SDS 87: angle=26.64°, P2=0.698, flat
#   SDS 88: angle=80.50°, P2=-0.459, upright
#   SDS 89: angle=153.26°, P2=0.696, flat
#   SDS 90: angle=143.20°, P2=0.462, flat
#   SDS 91: angle=86.93°, P2=-0.496, upright
#   SDS 92: angle=43.07°, P2=0.300, flat
#   SDS 93: angle=88.44°, P2=-0.499, upright
#   SDS 94: angle=131.53°, P2=0.159, upright
#   SDS 95: angle=136.00°, P2=0.276, flat
#   SDS 96: angle=80.16°, P2=-0.456, upright
#   SDS 97: angle=152.35°, P2=0.677, flat
#   SDS 98: angle=150.53°, P2=0.637, flat
#   SDS 99: angle=138.72°, P2=0.347, flat
#   SDS 100: angle=116.99°, P2=-0.191, upright
#   SDS 101: angle=92.59°, P2=-0.497, upright
#   SDS 102: angle=161.49°, P2=0.849, flat
#   SDS 103: angle=119.98°, P2=-0.125, upright
#   SDS 104: angle=145.01°, P2=0.507, flat
#   SDS 105: angle=136.82°, P2=0.298, flat
#   SDS 106: angle=116.76°, P2=-0.196, upright
#   SDS 107: angle=87.47°, P2=-0.497, upright
#   SDS 108: angle=73.12°, P2=-0.374, upright
#   SDS 109: angle=174.85°, P2=0.988, flat
#   SDS 110: angle=96.77°, P2=-0.479, upright
#   SDS 111: angle=127.91°, P2=0.066, upright
#   SDS 112: angle=52.28°, P2=0.061, upright
#   SDS 113: angle=46.94°, P2=0.199, upright
#   SDS 114: angle=158.82°, P2=0.804, flat
#   SDS 115: angle=63.34°, P2=-0.198, upright
#   SDS 116: angle=53.64°, P2=0.027, upright
#   SDS 117: angle=61.38°, P2=-0.156, upright
#   SDS 118: angle=47.87°, P2=0.175, upright
#   SDS 119: angle=171.33°, P2=0.966, flat
#   SDS 120: angle=37.41°, P2=0.446, flat
#   SDS 121: angle=151.47°, P2=0.658, flat
#   SDS 122: angle=168.42°, P2=0.940, flat
#   SDS 123: angle=168.24°, P2=0.938, flat
#   SDS 124: angle=154.13°, P2=0.714, flat
#   SDS 125: angle=167.24°, P2=0.927, flat
#   SDS 126: angle=77.07°, P2=-0.425, upright
#   SDS 127: angle=31.82°, P2=0.583, flat
#   SDS 128: angle=133.62°, P2=0.214, upright
#   SDS 129: angle=121.31°, P2=-0.095, upright
#   SDS 130: angle=105.19°, P2=-0.397, upright
#   SDS 131: angle=142.04°, P2=0.433, flat
#   SDS 132: angle=99.74°, P2=-0.457, upright
#   SDS 133: angle=40.11°, P2=0.377, flat
#   SDS 134: angle=98.04°, P2=-0.471, upright
#   SDS 135: angle=101.63°, P2=-0.439, upright
#   SDS 136: angle=70.70°, P2=-0.336, upright
#   SDS 137: angle=167.23°, P2=0.927, flat
#   SDS 138: angle=166.34°, P2=0.916, flat
#   SDS 139: angle=56.14°, P2=-0.034, upright
#   SDS 140: angle=62.51°, P2=-0.180, upright
#   SDS 141: angle=66.01°, P2=-0.252, upright
#   SDS 142: angle=103.81°, P2=-0.415, upright
#   SDS 143: angle=90.35°, P2=-0.500, upright
#   SDS 144: angle=117.94°, P2=-0.171, upright
#   SDS 145: angle=165.74°, P2=0.909, flat
#   SDS 146: angle=149.15°, P2=0.606, flat
#   SDS 147: angle=86.09°, P2=-0.493, upright
#   SDS 148: angle=138.73°, P2=0.347, flat
#   SDS 149: angle=128.12°, P2=0.072, upright
#   SDS 150: angle=70.12°, P2=-0.326, upright
#   SDS 151: angle=90.57°, P2=-0.500, upright
#   SDS 152: angle=79.97°, P2=-0.455, upright
#   SDS 153: angle=145.07°, P2=0.508, flat
#   SDS 154: angle=22.03°, P2=0.789, flat
#   SDS 155: angle=100.48°, P2=-0.450, upright
#   SDS 156: angle=66.33°, P2=-0.258, upright
#   SDS 157: angle=86.08°, P2=-0.493, upright
#   SDS 158: angle=82.30°, P2=-0.473, upright
#   SDS 159: angle=57.36°, P2=-0.064, upright
#   SDS 160: angle=165.86°, P2=0.910, flat
#   SDS 161: angle=142.97°, P2=0.456, flat
#   SDS 162: angle=150.27°, P2=0.631, flat
#   SDS 163: angle=113.69°, P2=-0.258, upright
#   SDS 164: angle=128.80°, P2=0.089, upright
#   SDS 165: angle=112.87°, P2=-0.273, upright
#   SDS 166: angle=96.19°, P2=-0.483, upright
#   SDS 167: angle=108.86°, P2=-0.343, upright
#   SDS 168: angle=92.22°, P2=-0.498, upright
#   SDS 169: angle=112.94°, P2=-0.272, upright
#   SDS 170: angle=91.18°, P2=-0.499, upright
#   SDS 171: angle=80.26°, P2=-0.457, upright
#   SDS 172: angle=69.08°, P2=-0.309, upright
#   SDS 173: angle=85.02°, P2=-0.489, upright
#   SDS 174: angle=162.26°, P2=0.861, flat
#   SDS 175: angle=65.23°, P2=-0.237, upright
#   SDS 176: angle=137.99°, P2=0.328, flat
#   SDS 177: angle=153.14°, P2=0.694, flat
#   SDS 178: angle=105.17°, P2=-0.397, upright
#   SDS 179: angle=88.86°, P2=-0.499, upright
#   SDS 180: angle=52.59°, P2=0.054, upright
#   SDS 181: angle=148.64°, P2=0.594, flat
#   SDS 182: angle=49.79°, P2=0.125, upright
#   SDS 183: angle=61.58°, P2=-0.160, upright
#   SDS 184: angle=120.01°, P2=-0.125, upright
#   SDS 185: angle=151.62°, P2=0.661, flat
#   SDS 186: angle=150.55°, P2=0.637, flat
#   SDS 187: angle=139.76°, P2=0.374, flat
#   SDS 188: angle=63.55°, P2=-0.202, upright
#   SDS 189: angle=131.19°, P2=0.150, upright
#   SDS 190: angle=16.76°, P2=0.875, flat
#   SDS 191: angle=80.70°, P2=-0.461, upright
#   SDS 192: angle=82.02°, P2=-0.471, upright
#   SDS 193: angle=73.26°, P2=-0.376, upright
#   SDS 194: angle=151.58°, P2=0.660, flat
#   SDS 195: angle=165.45°, P2=0.905, flat
#   SDS 196: angle=59.39°, P2=-0.111, upright
#   SDS 197: angle=92.86°, P2=-0.496, upright
#   SDS 198: angle=150.64°, P2=0.640, flat
#   SDS 199: angle=132.39°, P2=0.182, upright
#   SDS 200: angle=146.45°, P2=0.542, flat
# Frame 4:
#   SDS 1: angle=73.28°, P2=-0.376, upright
#   SDS 2: angle=119.75°, P2=-0.131, upright
#   SDS 3: angle=102.36°, P2=-0.431, upright
#   SDS 4: angle=142.26°, P2=0.438, flat
#   SDS 5: angle=38.43°, P2=0.420, flat
#   SDS 6: angle=76.83°, P2=-0.422, upright
#   SDS 7: angle=59.44°, P2=-0.112, upright
#   SDS 8: angle=22.96°, P2=0.772, flat
#   SDS 9: angle=67.04°, P2=-0.272, upright
#   SDS 10: angle=12.49°, P2=0.930, flat
#   SDS 11: angle=22.05°, P2=0.789, flat
#   SDS 12: angle=169.22°, P2=0.948, flat
#   SDS 13: angle=87.91°, P2=-0.498, upright
#   SDS 14: angle=101.84°, P2=-0.437, upright
#   SDS 15: angle=129.17°, P2=0.098, upright
#   SDS 16: angle=79.43°, P2=-0.450, upright
#   SDS 17: angle=58.95°, P2=-0.101, upright
#   SDS 18: angle=94.17°, P2=-0.492, upright
#   SDS 19: angle=77.61°, P2=-0.431, upright
#   SDS 20: angle=44.40°, P2=0.266, flat
#   SDS 21: angle=67.49°, P2=-0.280, upright
#   SDS 22: angle=55.70°, P2=-0.024, upright
#   SDS 23: angle=41.79°, P2=0.334, flat
#   SDS 24: angle=105.55°, P2=-0.392, upright
#   SDS 25: angle=43.91°, P2=0.278, flat
#   SDS 26: angle=106.38°, P2=-0.381, upright
#   SDS 27: angle=135.24°, P2=0.256, flat
#   SDS 28: angle=158.04°, P2=0.790, flat
#   SDS 29: angle=127.49°, P2=0.056, upright
#   SDS 30: angle=143.06°, P2=0.458, flat
#   SDS 31: angle=19.55°, P2=0.832, flat
#   SDS 32: angle=134.60°, P2=0.240, upright
#   SDS 33: angle=143.58°, P2=0.471, flat
#   SDS 34: angle=95.76°, P2=-0.485, upright
#   SDS 35: angle=100.03°, P2=-0.454, upright
#   SDS 36: angle=117.12°, P2=-0.188, upright
#   SDS 37: angle=61.76°, P2=-0.164, upright
#   SDS 38: angle=74.20°, P2=-0.389, upright
#   SDS 39: angle=64.43°, P2=-0.221, upright
#   SDS 40: angle=80.30°, P2=-0.457, upright
#   SDS 41: angle=118.34°, P2=-0.162, upright
#   SDS 42: angle=15.71°, P2=0.890, flat
#   SDS 43: angle=143.06°, P2=0.458, flat
#   SDS 44: angle=157.70°, P2=0.784, flat
#   SDS 45: angle=107.78°, P2=-0.360, upright
#   SDS 46: angle=24.12°, P2=0.749, flat
#   SDS 47: angle=39.68°, P2=0.388, flat
#   SDS 48: angle=101.39°, P2=-0.442, upright
#   SDS 49: angle=78.58°, P2=-0.441, upright
#   SDS 50: angle=133.74°, P2=0.217, upright
#   SDS 51: angle=83.22°, P2=-0.479, upright
#   SDS 52: angle=119.60°, P2=-0.134, upright
#   SDS 53: angle=104.72°, P2=-0.403, upright
#   SDS 54: angle=158.47°, P2=0.798, flat
#   SDS 55: angle=133.51°, P2=0.211, upright
#   SDS 56: angle=140.25°, P2=0.387, flat
#   SDS 57: angle=86.77°, P2=-0.495, upright
#   SDS 58: angle=75.59°, P2=-0.407, upright
#   SDS 59: angle=72.24°, P2=-0.361, upright
#   SDS 60: angle=125.27°, P2=0.000, upright
#   SDS 61: angle=55.91°, P2=-0.029, upright
#   SDS 62: angle=55.63°, P2=-0.022, upright
#   SDS 63: angle=58.71°, P2=-0.095, upright
#   SDS 64: angle=54.27°, P2=0.011, upright
#   SDS 65: angle=32.06°, P2=0.577, flat
#   SDS 66: angle=76.55°, P2=-0.419, upright
#   SDS 67: angle=132.88°, P2=0.194, upright
#   SDS 68: angle=47.71°, P2=0.179, upright
#   SDS 69: angle=157.93°, P2=0.788, flat
#   SDS 70: angle=122.34°, P2=-0.071, upright
#   SDS 71: angle=127.18°, P2=0.048, upright
#   SDS 72: angle=129.45°, P2=0.106, upright
#   SDS 73: angle=73.68°, P2=-0.382, upright
#   SDS 74: angle=113.46°, P2=-0.262, upright
#   SDS 75: angle=45.63°, P2=0.233, upright
#   SDS 76: angle=79.38°, P2=-0.449, upright
#   SDS 77: angle=104.70°, P2=-0.403, upright
#   SDS 78: angle=71.18°, P2=-0.344, upright
#   SDS 79: angle=102.74°, P2=-0.427, upright
#   SDS 80: angle=96.33°, P2=-0.482, upright
#   SDS 81: angle=132.00°, P2=0.172, upright
#   SDS 82: angle=48.65°, P2=0.155, upright
#   SDS 83: angle=127.89°, P2=0.066, upright
#   SDS 84: angle=93.24°, P2=-0.495, upright
#   SDS 85: angle=78.31°, P2=-0.438, upright
#   SDS 86: angle=152.64°, P2=0.683, flat
#   SDS 87: angle=27.52°, P2=0.680, flat
#   SDS 88: angle=95.90°, P2=-0.484, upright
#   SDS 89: angle=136.19°, P2=0.281, flat
#   SDS 90: angle=121.00°, P2=-0.102, upright
#   SDS 91: angle=67.46°, P2=-0.280, upright
#   SDS 92: angle=53.61°, P2=0.028, upright
#   SDS 93: angle=90.01°, P2=-0.500, upright
#   SDS 94: angle=108.29°, P2=-0.352, upright
#   SDS 95: angle=114.83°, P2=-0.235, upright
#   SDS 96: angle=130.88°, P2=0.143, upright
#   SDS 97: angle=128.31°, P2=0.076, upright
#   SDS 98: angle=147.09°, P2=0.557, flat
#   SDS 99: angle=175.10°, P2=0.989, flat
#   SDS 100: angle=143.94°, P2=0.480, flat
#   SDS 101: angle=68.53°, P2=-0.299, upright
#   SDS 102: angle=155.34°, P2=0.739, flat
#   SDS 103: angle=81.66°, P2=-0.468, upright
#   SDS 104: angle=154.09°, P2=0.714, flat
#   SDS 105: angle=104.06°, P2=-0.411, upright
#   SDS 106: angle=125.60°, P2=0.008, upright
#   SDS 107: angle=156.34°, P2=0.759, flat
#   SDS 108: angle=46.45°, P2=0.212, upright
#   SDS 109: angle=158.72°, P2=0.802, flat
#   SDS 110: angle=118.30°, P2=-0.163, upright
#   SDS 111: angle=154.25°, P2=0.717, flat
#   SDS 112: angle=59.96°, P2=-0.124, upright
#   SDS 113: angle=36.93°, P2=0.458, flat
#   SDS 114: angle=157.72°, P2=0.784, flat
#   SDS 115: angle=65.54°, P2=-0.243, upright
#   SDS 116: angle=36.40°, P2=0.472, flat
#   SDS 117: angle=98.08°, P2=-0.470, upright
#   SDS 118: angle=29.94°, P2=0.626, flat
#   SDS 119: angle=162.35°, P2=0.862, flat
#   SDS 120: angle=55.35°, P2=-0.015, upright
#   SDS 121: angle=133.91°, P2=0.221, upright
#   SDS 122: angle=139.11°, P2=0.357, flat
#   SDS 123: angle=154.41°, P2=0.720, flat
#   SDS 124: angle=154.43°, P2=0.721, flat
#   SDS 125: angle=137.51°, P2=0.316, flat
#   SDS 126: angle=117.93°, P2=-0.171, upright
#   SDS 127: angle=10.18°, P2=0.953, flat
#   SDS 128: angle=158.50°, P2=0.798, flat
#   SDS 129: angle=107.49°, P2=-0.365, upright
#   SDS 130: angle=110.80°, P2=-0.311, upright
#   SDS 131: angle=150.13°, P2=0.628, flat
#   SDS 132: angle=32.31°, P2=0.571, flat
#   SDS 133: angle=16.23°, P2=0.883, flat
#   SDS 134: angle=98.83°, P2=-0.465, upright
#   SDS 135: angle=164.74°, P2=0.896, flat
#   SDS 136: angle=104.84°, P2=-0.402, upright
#   SDS 137: angle=147.06°, P2=0.557, flat
#   SDS 138: angle=145.26°, P2=0.513, flat
#   SDS 139: angle=39.19°, P2=0.401, flat
#   SDS 140: angle=113.26°, P2=-0.266, upright
#   SDS 141: angle=33.31°, P2=0.548, flat
#   SDS 142: angle=76.65°, P2=-0.420, upright
#   SDS 143: angle=63.98°, P2=-0.211, upright
#   SDS 144: angle=100.08°, P2=-0.454, upright
#   SDS 145: angle=158.33°, P2=0.795, flat
#   SDS 146: angle=142.51°, P2=0.444, flat
#   SDS 147: angle=73.22°, P2=-0.375, upright
#   SDS 148: angle=153.32°, P2=0.698, flat
#   SDS 149: angle=147.28°, P2=0.562, flat
#   SDS 150: angle=48.17°, P2=0.167, upright
#   SDS 151: angle=113.56°, P2=-0.260, upright
#   SDS 152: angle=97.36°, P2=-0.475, upright
#   SDS 153: angle=153.37°, P2=0.699, flat
#   SDS 154: angle=75.95°, P2=-0.412, upright
#   SDS 155: angle=103.20°, P2=-0.422, upright
#   SDS 156: angle=25.88°, P2=0.714, flat
#   SDS 157: angle=127.76°, P2=0.063, upright
#   SDS 158: angle=87.83°, P2=-0.498, upright
#   SDS 159: angle=66.25°, P2=-0.257, upright
#   SDS 160: angle=130.49°, P2=0.132, upright
#   SDS 161: angle=158.07°, P2=0.791, flat
#   SDS 162: angle=166.26°, P2=0.915, flat
#   SDS 163: angle=114.91°, P2=-0.234, upright
#   SDS 164: angle=101.06°, P2=-0.445, upright
#   SDS 165: angle=152.51°, P2=0.680, flat
#   SDS 166: angle=139.72°, P2=0.373, flat
#   SDS 167: angle=78.27°, P2=-0.438, upright
#   SDS 168: angle=119.39°, P2=-0.139, upright
#   SDS 169: angle=148.92°, P2=0.600, flat
#   SDS 170: angle=63.04°, P2=-0.192, upright
#   SDS 171: angle=114.09°, P2=-0.250, upright
#   SDS 172: angle=96.14°, P2=-0.483, upright
#   SDS 173: angle=89.18°, P2=-0.500, upright
#   SDS 174: angle=172.42°, P2=0.974, flat
#   SDS 175: angle=65.54°, P2=-0.243, upright
#   SDS 176: angle=116.50°, P2=-0.201, upright
#   SDS 177: angle=145.96°, P2=0.530, flat
#   SDS 178: angle=102.39°, P2=-0.431, upright
#   SDS 179: angle=97.52°, P2=-0.474, upright
#   SDS 180: angle=90.52°, P2=-0.500, upright
#   SDS 181: angle=149.61°, P2=0.616, flat
#   SDS 182: angle=58.52°, P2=-0.091, upright
#   SDS 183: angle=52.11°, P2=0.066, upright
#   SDS 184: angle=101.15°, P2=-0.444, upright
#   SDS 185: angle=162.85°, P2=0.870, flat
#   SDS 186: angle=152.99°, P2=0.691, flat
#   SDS 187: angle=134.27°, P2=0.231, upright
#   SDS 188: angle=136.30°, P2=0.284, flat
#   SDS 189: angle=101.16°, P2=-0.444, upright
#   SDS 190: angle=11.84°, P2=0.937, flat
#   SDS 191: angle=65.44°, P2=-0.241, upright
#   SDS 192: angle=95.57°, P2=-0.486, upright
#   SDS 193: angle=25.44°, P2=0.723, flat
#   SDS 194: angle=120.12°, P2=-0.122, upright
#   SDS 195: angle=149.40°, P2=0.611, flat
#   SDS 196: angle=44.44°, P2=0.265, flat
#   SDS 197: angle=59.34°, P2=-0.110, upright
#   SDS 198: angle=137.67°, P2=0.320, flat
#   SDS 199: angle=108.88°, P2=-0.343, upright
#   SDS 200: angle=100.92°, P2=-0.446, upright
# Frame 5:
#   SDS 1: angle=71.26°, P2=-0.345, upright
#   SDS 2: angle=118.02°, P2=-0.169, upright
#   SDS 3: angle=114.19°, P2=-0.248, upright
#   SDS 4: angle=161.90°, P2=0.855, flat
#   SDS 5: angle=20.73°, P2=0.812, flat
#   SDS 6: angle=92.51°, P2=-0.497, upright
#   SDS 7: angle=139.62°, P2=0.370, flat
#   SDS 8: angle=26.34°, P2=0.705, flat
#   SDS 9: angle=38.21°, P2=0.426, flat
#   SDS 10: angle=59.21°, P2=-0.107, upright
#   SDS 11: angle=5.28°, P2=0.987, flat
#   SDS 12: angle=162.79°, P2=0.869, flat
#   SDS 13: angle=67.76°, P2=-0.285, upright
#   SDS 14: angle=119.90°, P2=-0.127, upright
#   SDS 15: angle=74.70°, P2=-0.396, upright
#   SDS 16: angle=98.95°, P2=-0.464, upright
#   SDS 17: angle=97.55°, P2=-0.474, upright
#   SDS 18: angle=98.63°, P2=-0.466, upright
#   SDS 19: angle=44.91°, P2=0.252, flat
#   SDS 20: angle=29.53°, P2=0.636, flat
#   SDS 21: angle=53.42°, P2=0.033, upright
#   SDS 22: angle=88.93°, P2=-0.499, upright
#   SDS 23: angle=13.53°, P2=0.918, flat
#   SDS 24: angle=78.46°, P2=-0.440, upright
#   SDS 25: angle=30.14°, P2=0.622, flat
#   SDS 26: angle=113.67°, P2=-0.258, upright
#   SDS 27: angle=151.79°, P2=0.665, flat
#   SDS 28: angle=129.88°, P2=0.117, upright
#   SDS 29: angle=105.20°, P2=-0.397, upright
#   SDS 30: angle=120.55°, P2=-0.112, upright
#   SDS 31: angle=42.59°, P2=0.313, flat
#   SDS 32: angle=126.51°, P2=0.031, upright
#   SDS 33: angle=158.07°, P2=0.791, flat
#   SDS 34: angle=57.70°, P2=-0.072, upright
#   SDS 35: angle=66.33°, P2=-0.258, upright
#   SDS 36: angle=122.54°, P2=-0.066, upright
#   SDS 37: angle=53.56°, P2=0.029, upright
#   SDS 38: angle=53.87°, P2=0.021, upright
#   SDS 39: angle=48.95°, P2=0.147, upright
#   SDS 40: angle=98.31°, P2=-0.469, upright
#   SDS 41: angle=96.11°, P2=-0.483, upright
#   SDS 42: angle=5.96°, P2=0.984, flat
#   SDS 43: angle=146.84°, P2=0.551, flat
#   SDS 44: angle=167.33°, P2=0.928, flat
#   SDS 45: angle=57.21°, P2=-0.060, upright
#   SDS 46: angle=8.65°, P2=0.966, flat
#   SDS 47: angle=53.04°, P2=0.042, upright
#   SDS 48: angle=83.32°, P2=-0.480, upright
#   SDS 49: angle=68.42°, P2=-0.297, upright
#   SDS 50: angle=117.74°, P2=-0.175, upright
#   SDS 51: angle=76.51°, P2=-0.418, upright
#   SDS 52: angle=92.72°, P2=-0.497, upright
#   SDS 53: angle=130.17°, P2=0.124, upright
#   SDS 54: angle=127.45°, P2=0.055, upright
#   SDS 55: angle=125.91°, P2=0.016, upright
#   SDS 56: angle=156.70°, P2=0.765, flat
#   SDS 57: angle=76.36°, P2=-0.417, upright
#   SDS 58: angle=67.75°, P2=-0.285, upright
#   SDS 59: angle=100.89°, P2=-0.446, upright
#   SDS 60: angle=89.08°, P2=-0.500, upright
#   SDS 61: angle=101.42°, P2=-0.441, upright
#   SDS 62: angle=59.76°, P2=-0.120, upright
#   SDS 63: angle=66.66°, P2=-0.264, upright
#   SDS 64: angle=55.86°, P2=-0.028, upright
#   SDS 65: angle=37.66°, P2=0.440, flat
#   SDS 66: angle=107.40°, P2=-0.366, upright
#   SDS 67: angle=147.58°, P2=0.569, flat
#   SDS 68: angle=36.55°, P2=0.468, flat
#   SDS 69: angle=161.09°, P2=0.842, flat
#   SDS 70: angle=103.57°, P2=-0.417, upright
#   SDS 71: angle=140.56°, P2=0.395, flat
#   SDS 72: angle=130.00°, P2=0.120, upright
#   SDS 73: angle=59.65°, P2=-0.117, upright
#   SDS 74: angle=98.00°, P2=-0.471, upright
#   SDS 75: angle=102.81°, P2=-0.426, upright
#   SDS 76: angle=42.15°, P2=0.324, flat
#   SDS 77: angle=122.86°, P2=-0.058, upright
#   SDS 78: angle=112.72°, P2=-0.276, upright
#   SDS 79: angle=88.16°, P2=-0.498, upright
#   SDS 80: angle=92.39°, P2=-0.497, upright
#   SDS 81: angle=133.99°, P2=0.223, upright
#   SDS 82: angle=52.67°, P2=0.052, upright
#   SDS 83: angle=121.16°, P2=-0.098, upright
#   SDS 84: angle=74.57°, P2=-0.394, upright
#   SDS 85: angle=78.05°, P2=-0.436, upright
#   SDS 86: angle=136.60°, P2=0.292, flat
#   SDS 87: angle=63.50°, P2=-0.201, upright
#   SDS 88: angle=97.40°, P2=-0.475, upright
#   SDS 89: angle=134.35°, P2=0.233, upright
#   SDS 90: angle=105.96°, P2=-0.387, upright
#   SDS 91: angle=64.79°, P2=-0.228, upright
#   SDS 92: angle=50.27°, P2=0.113, upright
#   SDS 93: angle=84.29°, P2=-0.485, upright
#   SDS 94: angle=134.34°, P2=0.233, upright
#   SDS 95: angle=138.46°, P2=0.340, flat
#   SDS 96: angle=124.13°, P2=-0.028, upright
#   SDS 97: angle=137.79°, P2=0.323, flat
#   SDS 98: angle=159.07°, P2=0.809, flat
#   SDS 99: angle=102.12°, P2=-0.434, upright
#   SDS 100: angle=160.59°, P2=0.834, flat
#   SDS 101: angle=82.28°, P2=-0.473, upright
#   SDS 102: angle=150.77°, P2=0.642, flat
#   SDS 103: angle=90.68°, P2=-0.500, upright
#   SDS 104: angle=125.04°, P2=-0.006, upright
#   SDS 105: angle=94.12°, P2=-0.492, upright
#   SDS 106: angle=80.42°, P2=-0.458, upright
#   SDS 107: angle=153.70°, P2=0.706, flat
#   SDS 108: angle=35.46°, P2=0.495, flat
#   SDS 109: angle=140.48°, P2=0.393, flat
#   SDS 110: angle=124.51°, P2=-0.019, upright
#   SDS 111: angle=139.06°, P2=0.356, flat
#   SDS 112: angle=30.14°, P2=0.622, flat
#   SDS 113: angle=122.11°, P2=-0.076, upright
#   SDS 114: angle=145.24°, P2=0.512, flat
#   SDS 115: angle=59.14°, P2=-0.105, upright
#   SDS 116: angle=60.31°, P2=-0.132, upright
#   SDS 117: angle=90.19°, P2=-0.500, upright
#   SDS 118: angle=15.97°, P2=0.887, flat
#   SDS 119: angle=157.22°, P2=0.775, flat
#   SDS 120: angle=89.73°, P2=-0.500, upright
# ...
#   SDS 101: angle=163.86°, P2=0.884, flat
#   SDS 102: angle=118.05°, P2=-0.168, upright
#   SDS 103: angle=115.29°, P2=-0.226, upright
#   SDS 104: angle=24.81°, P2=0.736, flat
#   SDS 105: angle=109.49°, P2=-0.333, upright
#   SDS 106: angle=66.32°, P2=-0.258, upright
#   SDS 107: angle=3.49°, P2=0.994, flat
#   SDS 108: angle=142.66°, P2=0.448, flat
#   SDS 109: angle=101.64°, P2=-0.439, upright
#   SDS 110: angle=112.23°, P2=-0.285, upright
#   SDS 111: angle=128.93°, P2=0.092, upright
#   SDS 112: angle=128.99°, P2=0.094, upright
#   SDS 113: angle=129.37°, P2=0.103, upright
#   SDS 114: angle=62.30°, P2=-0.176, upright
#   SDS 115: angle=65.02°, P2=-0.232, upright
#   SDS 116: angle=96.15°, P2=-0.483, upright
#   SDS 117: angle=29.79°, P2=0.630, flat
#   SDS 118: angle=43.30°, P2=0.294, flat
#   SDS 119: angle=162.50°, P2=0.864, flat
#   SDS 120: angle=164.02°, P2=0.886, flat
#   SDS 121: angle=82.48°, P2=-0.474, upright
#   SDS 122: angle=66.85°, P2=-0.268, upright
#   SDS 123: angle=71.98°, P2=-0.356, upright
#   SDS 124: angle=14.42°, P2=0.907, flat
#   SDS 125: angle=137.29°, P2=0.310, flat
#   SDS 126: angle=16.63°, P2=0.877, flat
#   SDS 127: angle=108.91°, P2=-0.342, upright
#   SDS 128: angle=85.11°, P2=-0.489, upright
#   SDS 129: angle=28.83°, P2=0.651, flat
#   SDS 130: angle=134.05°, P2=0.225, upright
#   SDS 131: angle=20.01°, P2=0.824, flat
#   SDS 132: angle=103.67°, P2=-0.416, upright
#   SDS 133: angle=108.03°, P2=-0.356, upright
#   SDS 134: angle=76.86°, P2=-0.422, upright
#   SDS 135: angle=168.15°, P2=0.937, flat
#   SDS 136: angle=159.41°, P2=0.815, flat
#   SDS 137: angle=101.74°, P2=-0.438, upright
#   SDS 138: angle=136.51°, P2=0.290, flat
#   SDS 139: angle=136.00°, P2=0.276, flat
#   SDS 140: angle=35.34°, P2=0.498, flat
#   SDS 141: angle=22.20°, P2=0.786, flat
#   SDS 142: angle=99.85°, P2=-0.456, upright
#   SDS 143: angle=164.10°, P2=0.887, flat
#   SDS 144: angle=159.37°, P2=0.814, flat
#   SDS 145: angle=129.63°, P2=0.110, upright
#   SDS 146: angle=158.68°, P2=0.802, flat
#   SDS 147: angle=95.07°, P2=-0.488, upright
#   SDS 148: angle=14.13°, P2=0.911, flat
#   SDS 149: angle=74.85°, P2=-0.398, upright
#   SDS 150: angle=119.14°, P2=-0.144, upright
#   SDS 151: angle=72.32°, P2=-0.362, upright
#   SDS 152: angle=129.90°, P2=0.117, upright
#   SDS 153: angle=93.49°, P2=-0.494, upright
#   SDS 154: angle=84.68°, P2=-0.487, upright
#   SDS 155: angle=29.20°, P2=0.643, flat
#   SDS 156: angle=84.82°, P2=-0.488, upright
#   SDS 157: angle=104.08°, P2=-0.411, upright
#   SDS 158: angle=48.79°, P2=0.151, upright
#   SDS 159: angle=168.28°, P2=0.938, flat
#   SDS 160: angle=32.35°, P2=0.571, flat
#   SDS 161: angle=57.44°, P2=-0.066, upright
#   SDS 162: angle=64.50°, P2=-0.222, upright
#   SDS 163: angle=132.24°, P2=0.178, upright
#   SDS 164: angle=63.92°, P2=-0.210, upright
#   SDS 165: angle=47.16°, P2=0.194, upright
#   SDS 166: angle=112.28°, P2=-0.284, upright
#   SDS 167: angle=86.72°, P2=-0.495, upright
#   SDS 168: angle=49.57°, P2=0.131, upright
#   SDS 169: angle=74.70°, P2=-0.396, upright
#   SDS 170: angle=16.94°, P2=0.873, flat
#   SDS 171: angle=105.06°, P2=-0.399, upright
#   SDS 172: angle=9.69°, P2=0.958, flat
#   SDS 173: angle=55.20°, P2=-0.011, upright
#   SDS 174: angle=126.34°, P2=0.027, upright
#   SDS 175: angle=128.85°, P2=0.090, upright
#   SDS 176: angle=141.83°, P2=0.427, flat
#   SDS 177: angle=76.27°, P2=-0.415, upright
#   SDS 178: angle=56.16°, P2=-0.035, upright
#   SDS 179: angle=106.95°, P2=-0.372, upright
#   SDS 180: angle=148.17°, P2=0.583, flat
#   SDS 181: angle=28.70°, P2=0.654, flat
#   SDS 182: angle=18.78°, P2=0.845, flat
#   SDS 183: angle=147.14°, P2=0.558, flat
#   SDS 184: angle=13.34°, P2=0.920, flat
#   SDS 185: angle=60.11°, P2=-0.128, upright
#   SDS 186: angle=176.40°, P2=0.994, flat
#   SDS 187: angle=99.67°, P2=-0.458, upright
#   SDS 188: angle=154.14°, P2=0.715, flat
#   SDS 189: angle=166.85°, P2=0.922, flat
#   SDS 190: angle=53.09°, P2=0.041, upright
#   SDS 191: angle=57.48°, P2=-0.066, upright
#   SDS 192: angle=30.72°, P2=0.609, flat
#   SDS 193: angle=66.00°, P2=-0.252, upright
#   SDS 194: angle=72.86°, P2=-0.370, upright
#   SDS 195: angle=80.18°, P2=-0.456, upright
#   SDS 196: angle=170.70°, P2=0.961, flat
#   SDS 197: angle=29.38°, P2=0.639, flat
#   SDS 198: angle=24.41°, P2=0.744, flat
#   SDS 199: angle=12.58°, P2=0.929, flat
#   SDS 200: angle=7.80°, P2=0.972, flat
# Frame 276:
#   SDS 1: angle=90.23°, P2=-0.500, upright
#   SDS 2: angle=133.93°, P2=0.222, upright
#   SDS 3: angle=177.35°, P2=0.997, flat
#   SDS 4: angle=29.81°, P2=0.629, flat
#   SDS 5: angle=33.58°, P2=0.541, flat
#   SDS 6: angle=26.10°, P2=0.710, flat
#   SDS 7: angle=66.75°, P2=-0.266, upright
#   SDS 8: angle=165.78°, P2=0.909, flat
#   SDS 9: angle=89.15°, P2=-0.500, upright
#   SDS 10: angle=152.92°, P2=0.689, flat
#   SDS 11: angle=7.47°, P2=0.975, flat
#   SDS 12: angle=169.80°, P2=0.953, flat
#   SDS 13: angle=120.48°, P2=-0.114, upright
#   SDS 14: angle=89.98°, P2=-0.500, upright
#   SDS 15: angle=62.89°, P2=-0.189, upright
#   SDS 16: angle=25.10°, P2=0.730, flat
#   SDS 17: angle=24.36°, P2=0.745, flat
#   SDS 18: angle=72.57°, P2=-0.365, upright
#   SDS 19: angle=94.34°, P2=-0.491, upright
#   SDS 20: angle=64.77°, P2=-0.228, upright
#   SDS 21: angle=92.83°, P2=-0.496, upright
#   SDS 22: angle=122.01°, P2=-0.079, upright
#   SDS 23: angle=98.09°, P2=-0.470, upright
#   SDS 24: angle=146.45°, P2=0.542, flat
#   SDS 25: angle=84.81°, P2=-0.488, upright
#   SDS 26: angle=47.77°, P2=0.178, upright
#   SDS 27: angle=128.45°, P2=0.080, upright
#   SDS 28: angle=110.34°, P2=-0.319, upright
#   SDS 29: angle=62.93°, P2=-0.189, upright
#   SDS 30: angle=43.47°, P2=0.290, flat
#   SDS 31: angle=12.39°, P2=0.931, flat
#   SDS 32: angle=110.69°, P2=-0.313, upright
#   SDS 33: angle=52.77°, P2=0.049, upright
#   SDS 34: angle=121.25°, P2=-0.096, upright
#   SDS 35: angle=156.94°, P2=0.770, flat
#   SDS 36: angle=132.04°, P2=0.173, upright
#   SDS 37: angle=123.94°, P2=-0.032, upright
#   SDS 38: angle=10.77°, P2=0.948, flat
#   SDS 39: angle=30.61°, P2=0.611, flat
#   SDS 40: angle=31.51°, P2=0.590, flat
#   SDS 41: angle=117.02°, P2=-0.190, upright
#   SDS 42: angle=8.87°, P2=0.964, flat
#   SDS 43: angle=53.37°, P2=0.034, upright
#   SDS 44: angle=146.66°, P2=0.547, flat
#   SDS 45: angle=89.48°, P2=-0.500, upright
#   SDS 46: angle=13.95°, P2=0.913, flat
#   SDS 47: angle=15.72°, P2=0.890, flat
#   SDS 48: angle=146.11°, P2=0.534, flat
#   SDS 49: angle=86.13°, P2=-0.493, upright
#   SDS 50: angle=65.95°, P2=-0.251, upright
#   SDS 51: angle=70.93°, P2=-0.340, upright
#   SDS 52: angle=155.70°, P2=0.746, flat
#   SDS 53: angle=81.64°, P2=-0.468, upright
#   SDS 54: angle=116.66°, P2=-0.198, upright
#   SDS 55: angle=11.09°, P2=0.945, flat
#   SDS 56: angle=158.85°, P2=0.805, flat
#   SDS 57: angle=115.89°, P2=-0.214, upright
#   SDS 58: angle=94.90°, P2=-0.489, upright
#   SDS 59: angle=110.09°, P2=-0.323, upright
#   SDS 60: angle=154.41°, P2=0.720, flat
#   SDS 61: angle=163.14°, P2=0.874, flat
#   SDS 62: angle=35.92°, P2=0.484, flat
#   SDS 63: angle=131.93°, P2=0.170, upright
#   SDS 64: angle=33.93°, P2=0.533, flat
#   SDS 65: angle=122.87°, P2=-0.058, upright
#   SDS 66: angle=84.21°, P2=-0.485, upright
#   SDS 67: angle=97.45°, P2=-0.475, upright
#   SDS 68: angle=157.17°, P2=0.774, flat
#   SDS 69: angle=103.27°, P2=-0.421, upright
#   SDS 70: angle=125.63°, P2=0.009, upright
#   SDS 71: angle=143.15°, P2=0.461, flat
#   SDS 72: angle=89.07°, P2=-0.500, upright
#   SDS 73: angle=77.83°, P2=-0.433, upright
#   SDS 74: angle=104.52°, P2=-0.406, upright
#   SDS 75: angle=85.64°, P2=-0.491, upright
#   SDS 76: angle=163.20°, P2=0.875, flat
#   SDS 77: angle=128.51°, P2=0.082, upright
#   SDS 78: angle=66.30°, P2=-0.258, upright
#   SDS 79: angle=86.35°, P2=-0.494, upright
#   SDS 80: angle=75.55°, P2=-0.407, upright
#   SDS 81: angle=97.88°, P2=-0.472, upright
#   SDS 82: angle=126.25°, P2=0.024, upright
#   SDS 83: angle=143.91°, P2=0.480, flat
#   SDS 84: angle=164.86°, P2=0.898, flat
#   SDS 85: angle=89.47°, P2=-0.500, upright
#   SDS 86: angle=36.71°, P2=0.464, flat
#   SDS 87: angle=110.86°, P2=-0.310, upright
#   SDS 88: angle=89.35°, P2=-0.500, upright
#   SDS 89: angle=90.69°, P2=-0.500, upright
#   SDS 90: angle=74.71°, P2=-0.396, upright
#   SDS 91: angle=87.65°, P2=-0.497, upright
#   SDS 92: angle=98.21°, P2=-0.469, upright
#   SDS 93: angle=69.18°, P2=-0.311, upright
#   SDS 94: angle=38.44°, P2=0.420, flat
#   SDS 95: angle=149.94°, P2=0.624, flat
#   SDS 96: angle=69.46°, P2=-0.315, upright
#   SDS 97: angle=53.69°, P2=0.026, upright
#   SDS 98: angle=12.66°, P2=0.928, flat
#   SDS 99: angle=43.22°, P2=0.297, flat
#   SDS 100: angle=95.97°, P2=-0.484, upright
#   SDS 101: angle=132.34°, P2=0.180, upright
#   SDS 102: angle=125.24°, P2=-0.001, upright
#   SDS 103: angle=99.15°, P2=-0.462, upright
#   SDS 104: angle=21.88°, P2=0.792, flat
#   SDS 105: angle=94.11°, P2=-0.492, upright
#   SDS 106: angle=88.09°, P2=-0.498, upright
#   SDS 107: angle=26.72°, P2=0.697, flat
#   SDS 108: angle=159.47°, P2=0.816, flat
#   SDS 109: angle=134.81°, P2=0.245, upright
#   SDS 110: angle=104.49°, P2=-0.406, upright
#   SDS 111: angle=123.95°, P2=-0.032, upright
#   SDS 112: angle=117.07°, P2=-0.189, upright
#   SDS 113: angle=83.68°, P2=-0.482, upright
#   SDS 114: angle=64.75°, P2=-0.227, upright
#   SDS 115: angle=58.34°, P2=-0.087, upright
#   SDS 116: angle=83.42°, P2=-0.480, upright
#   SDS 117: angle=62.80°, P2=-0.187, upright
#   SDS 118: angle=23.46°, P2=0.762, flat
#   SDS 119: angle=159.04°, P2=0.808, flat
#   SDS 120: angle=156.66°, P2=0.764, flat
#   SDS 121: angle=82.02°, P2=-0.471, upright
#   SDS 122: angle=132.85°, P2=0.194, upright
#   SDS 123: angle=65.95°, P2=-0.251, upright
#   SDS 124: angle=35.93°, P2=0.484, flat
#   SDS 125: angle=114.64°, P2=-0.239, upright
#   SDS 126: angle=8.69°, P2=0.966, flat
#   SDS 127: angle=60.81°, P2=-0.143, upright
#   SDS 128: angle=65.05°, P2=-0.233, upright
#   SDS 129: angle=50.80°, P2=0.099, upright
#   SDS 130: angle=97.96°, P2=-0.471, upright
#   SDS 131: angle=18.63°, P2=0.847, flat
#   SDS 132: angle=104.18°, P2=-0.410, upright
#   SDS 133: angle=91.26°, P2=-0.499, upright
#   SDS 134: angle=84.64°, P2=-0.487, upright
#   SDS 135: angle=164.85°, P2=0.897, flat
#   SDS 136: angle=169.58°, P2=0.951, flat
#   SDS 137: angle=131.90°, P2=0.169, upright
#   SDS 138: angle=121.99°, P2=-0.079, upright
#   SDS 139: angle=116.60°, P2=-0.199, upright
#   SDS 140: angle=66.09°, P2=-0.254, upright
#   SDS 141: angle=25.22°, P2=0.728, flat
#   SDS 142: angle=99.39°, P2=-0.460, upright
#   SDS 143: angle=165.79°, P2=0.910, flat
#   SDS 144: angle=161.58°, P2=0.850, flat
#   SDS 145: angle=92.42°, P2=-0.497, upright
#   SDS 146: angle=159.21°, P2=0.811, flat
#   SDS 147: angle=93.37°, P2=-0.495, upright
#   SDS 148: angle=6.83°, P2=0.979, flat
#   SDS 149: angle=114.87°, P2=-0.235, upright
#   SDS 150: angle=65.15°, P2=-0.235, upright
#   SDS 151: angle=106.43°, P2=-0.380, upright
#   SDS 152: angle=120.45°, P2=-0.115, upright
#   SDS 153: angle=98.14°, P2=-0.470, upright
#   SDS 154: angle=123.26°, P2=-0.049, upright
#   SDS 155: angle=16.24°, P2=0.883, flat
#   SDS 156: angle=69.21°, P2=-0.311, upright
#   SDS 157: angle=107.25°, P2=-0.368, upright
#   SDS 158: angle=40.08°, P2=0.378, flat
#   SDS 159: angle=173.24°, P2=0.979, flat
#   SDS 160: angle=25.46°, P2=0.723, flat
#   SDS 161: angle=40.68°, P2=0.363, flat
#   SDS 162: angle=32.23°, P2=0.573, flat
#   SDS 163: angle=107.23°, P2=-0.368, upright
#   SDS 164: angle=67.76°, P2=-0.285, upright
#   SDS 165: angle=55.19°, P2=-0.011, upright
#   SDS 166: angle=81.68°, P2=-0.469, upright
#   SDS 167: angle=73.75°, P2=-0.383, upright
#   SDS 168: angle=13.10°, P2=0.923, flat
#   SDS 169: angle=73.05°, P2=-0.373, upright
#   SDS 170: angle=9.58°, P2=0.958, flat
#   SDS 171: angle=75.27°, P2=-0.403, upright
#   SDS 172: angle=9.70°, P2=0.957, flat
#   SDS 173: angle=45.10°, P2=0.247, upright
#   SDS 174: angle=128.51°, P2=0.081, upright
#   SDS 175: angle=139.39°, P2=0.364, flat
#   SDS 176: angle=115.13°, P2=-0.229, upright
#   SDS 177: angle=90.06°, P2=-0.500, upright
#   SDS 178: angle=92.12°, P2=-0.498, upright
#   SDS 179: angle=94.30°, P2=-0.492, upright
#   SDS 180: angle=150.02°, P2=0.625, flat
#   SDS 181: angle=47.27°, P2=0.191, upright
#   SDS 182: angle=15.47°, P2=0.893, flat
#   SDS 183: angle=117.77°, P2=-0.174, upright
#   SDS 184: angle=25.40°, P2=0.724, flat
#   SDS 185: angle=61.76°, P2=-0.164, upright
#   SDS 186: angle=142.47°, P2=0.443, flat
#   SDS 187: angle=97.49°, P2=-0.474, upright
#   SDS 188: angle=157.49°, P2=0.780, flat
#   SDS 189: angle=136.99°, P2=0.302, flat
#   SDS 190: angle=86.94°, P2=-0.496, upright
#   SDS 191: angle=10.68°, P2=0.948, flat
#   SDS 192: angle=16.45°, P2=0.880, flat
#   SDS 193: angle=37.04°, P2=0.456, flat
#   SDS 194: angle=77.08°, P2=-0.425, upright
#   SDS 195: angle=76.09°, P2=-0.413, upright
#   SDS 196: angle=137.54°, P2=0.316, flat
#   SDS 197: angle=30.37°, P2=0.617, flat
#   SDS 198: angle=101.30°, P2=-0.442, upright
#   SDS 199: angle=26.10°, P2=0.710, flat
#   SDS 200: angle=22.10°, P2=0.788, flat
# Frame 277:
#   SDS 1: angle=99.28°, P2=-0.461, upright
#   SDS 2: angle=133.54°, P2=0.212, upright
#   SDS 3: angle=122.02°, P2=-0.078, upright
#   SDS 4: angle=79.54°, P2=-0.451, upright
#   SDS 5: angle=32.33°, P2=0.571, flat
#   SDS 6: angle=39.90°, P2=0.383, flat
#   SDS 7: angle=36.49°, P2=0.470, flat
#   SDS 8: angle=169.03°, P2=0.946, flat
#   SDS 9: angle=69.98°, P2=-0.324, upright
#   SDS 10: angle=163.98°, P2=0.886, flat
#   SDS 11: angle=15.70°, P2=0.890, flat
#   SDS 12: angle=155.90°, P2=0.750, flat
#   SDS 13: angle=77.05°, P2=-0.425, upright
#   SDS 14: angle=103.65°, P2=-0.416, upright
#   SDS 15: angle=67.83°, P2=-0.286, upright
#   SDS 16: angle=29.43°, P2=0.638, flat
#   SDS 17: angle=6.19°, P2=0.983, flat
#   SDS 18: angle=15.65°, P2=0.891, flat
#   SDS 19: angle=71.86°, P2=-0.355, upright
#   SDS 20: angle=53.41°, P2=0.033, upright
#   SDS 21: angle=86.96°, P2=-0.496, upright
#   SDS 22: angle=103.31°, P2=-0.420, upright
#   SDS 23: angle=114.74°, P2=-0.237, upright
#   SDS 24: angle=160.02°, P2=0.825, flat
#   SDS 25: angle=85.36°, P2=-0.490, upright
#   SDS 26: angle=46.83°, P2=0.202, upright
#   SDS 27: angle=151.33°, P2=0.655, flat
#   SDS 28: angle=79.12°, P2=-0.447, upright
#   SDS 29: angle=53.43°, P2=0.032, upright
#   SDS 30: angle=33.27°, P2=0.549, flat
#   SDS 31: angle=51.64°, P2=0.078, upright
#   SDS 32: angle=102.48°, P2=-0.430, upright
#   SDS 33: angle=46.60°, P2=0.208, upright
#   SDS 34: angle=129.32°, P2=0.102, upright
#   SDS 35: angle=118.62°, P2=-0.156, upright
#   SDS 36: angle=91.38°, P2=-0.499, upright
#   SDS 37: angle=143.12°, P2=0.460, flat
#   SDS 38: angle=6.65°, P2=0.980, flat
#   SDS 39: angle=29.35°, P2=0.640, flat
#   SDS 40: angle=29.91°, P2=0.627, flat
#   SDS 41: angle=89.11°, P2=-0.500, upright
#   SDS 42: angle=22.91°, P2=0.773, flat
#   SDS 43: angle=86.87°, P2=-0.496, upright
#   SDS 44: angle=138.06°, P2=0.330, flat
#   SDS 45: angle=86.26°, P2=-0.494, upright
#   SDS 46: angle=11.85°, P2=0.937, flat
#   SDS 47: angle=13.04°, P2=0.924, flat
#   SDS 48: angle=121.32°, P2=-0.095, upright
#   SDS 49: angle=62.08°, P2=-0.171, upright
#   SDS 50: angle=51.44°, P2=0.083, upright
#   SDS 51: angle=54.27°, P2=0.011, upright
#   SDS 52: angle=154.22°, P2=0.716, flat
#   SDS 53: angle=58.86°, P2=-0.099, upright
#   SDS 54: angle=128.90°, P2=0.092, upright
#   SDS 55: angle=26.42°, P2=0.703, flat
#   SDS 56: angle=166.41°, P2=0.917, flat
#   SDS 57: angle=164.38°, P2=0.891, flat
#   SDS 58: angle=99.34°, P2=-0.460, upright
#   SDS 59: angle=93.11°, P2=-0.496, upright
#   SDS 60: angle=155.18°, P2=0.736, flat
#   SDS 61: angle=159.97°, P2=0.824, flat
#   SDS 62: angle=26.10°, P2=0.710, flat
#   SDS 63: angle=120.13°, P2=-0.122, upright
#   SDS 64: angle=51.09°, P2=0.092, upright
#   SDS 65: angle=138.09°, P2=0.331, flat
#   SDS 66: angle=83.18°, P2=-0.479, upright
#   SDS 67: angle=83.10°, P2=-0.478, upright
#   SDS 68: angle=142.01°, P2=0.432, flat
#   SDS 69: angle=85.83°, P2=-0.492, upright
#   SDS 70: angle=110.10°, P2=-0.323, upright
#   SDS 71: angle=140.24°, P2=0.386, flat
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
import pandas as pd

# ===== 整理成 long-format 表格 =====
num_frames = traj_CF_straight_o_00.n_frames

frame_list = []
sds_list = []
angle_list = []
p2_list = []
orientation_list = []

for i in range(num_frames):
    for j in range(num_sds):
        frame_list.append(i)
        sds_list.append(j+1)
        angle_list.append(angles[i, j])
        p2_list.append(p2_values[i, j])
        orientation_list.append(orientation_labels[i, j])

df = pd.DataFrame({
    "Frame": frame_list,
    "SDS_ID": sds_list,
    "Angle_deg": angle_list,
    "P2": p2_list,
    "Orientation": orientation_list
})

# ===== 存成 CSV =====
output_file = "200sds.csv"
df.to_csv(output_file, index=False)

print(f"Data saved to {output_file}")
# Out:
# Data saved to 100sds.csv
